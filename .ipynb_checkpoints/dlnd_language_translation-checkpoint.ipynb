# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of each sentence from `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    
    source_id_text = []
    target_id_text = []
#     print(source_vocab_to_int)
    
    source_phrases = source_text.split("\n")
    for phrase in source_phrases:
#         print(phrase)
        phrase_array = []
        for word in phrase.split(" "):
            if word != '':
                phrase_array.append(source_vocab_to_int[word])
        source_id_text.append(phrase_array)
#     print(source_id_text)        
    
    target_phrases = target_text.split("\n")
    for phrase in target_phrases:
#         print(phrase)
        phrase_array = []
        for word in phrase.split(" "):
            if word != '':
                phrase_array.append(target_vocab_to_int[word])
        phrase_array.append(target_vocab_to_int["<EOS>"])
        target_id_text.append(phrase_array)
     
    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) in [LooseVersion('1.0.0'), LooseVersion('1.0.1')], 'This project requires TensorFlow version 1.0  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
#
# Return the placeholders in the following the tuple (Input, Targets, Learing Rate, Keep Probability)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    # TODO: Implement Function
    inputs = tf.placeholder(tf.int32, shape=[None, None], name="input")
    targets = tf.placeholder(tf.int32, shape=[None, None], name="targets")
    learning_rate = tf.placeholder(tf.float32, name="learning_rate")
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    return inputs, targets, learning_rate, keep_prob

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoding Input
# Implement `process_decoding_input` using TensorFlow to remove the last word id from each batch in `target_data` and concat the GO ID to the beginning of each batch.

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for dencoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    print("target_data", target_data)
    print("target_vocab_to_int", target_vocab_to_int)
    print("batch_size", batch_size)
    
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)

    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
# Out:
# target_data Tensor("Placeholder:0", shape=(2, 3), dtype=int32)
# target_vocab_to_int {'<GO>': 3}
# batch_size 2
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer using [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn).

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """
    
     # TODO: Implement Function
    cell = tf.contrib.rnn.LSTMCell(rnn_size, state_is_tuple=True)
    cell = tf.contrib.rnn.DropoutWrapper(cell, output_keep_prob=keep_prob)
    cell = tf.contrib.rnn.MultiRNNCell([cell] * num_layers, state_is_tuple=True)
    _, enc_state = tf.nn.dynamic_rnn(cell = cell, inputs = rnn_inputs, dtype=tf.float32)

    return enc_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create training logits using [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).  Apply the `output_fn` to the [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) outputs.

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """

    train_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    train_pred, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, train_decoder_fn, dec_embed_input, sequence_length, scope=decoding_scope)    
    train_logits =  output_fn(train_pred)
    return train_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference logits using [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: The maximum allowed time steps to decode
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """
    # TODO: Implement Function
    inf_decoder = tf.contrib.seq2seq.simple_decoder_fn_inference(output_fn, encoder_state, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, dtype=tf.int32, name="inf_decoder_fn")
    dec_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob=keep_prob)
    inf_logits, _, _ =tf.contrib.seq2seq.dynamic_rnn_decoder(cell = dec_cell, decoder_fn = inf_decoder, scope = decoding_scope, name = "inf_logits")
    return inf_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# - Create RNN cell for decoding using `rnn_size` and `num_layers`.
# - Create the output fuction using [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) to transform it's input, logits, to class logits.
# - Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` function to get the training logits.
# - Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    
    # TODO: Implement Function
    start_of_sequence_id = target_vocab_to_int['<GO>']
    end_of_sequence_id = target_vocab_to_int['<EOS>']
        
    with tf.variable_scope("decoding") as decoding_scope:
        lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
        cell = tf.contrib.rnn.MultiRNNCell([lstm]*num_layers)
        output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, None, scope=decoding_scope)
        train_logits = decoding_layer_train(encoder_state, cell, dec_embed_input, sequence_length,decoding_scope, output_fn, keep_prob)
        decoding_scope.reuse_variables()
        inference_logits = decoding_layer_infer(encoder_state, cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, sequence_length, vocab_size, decoding_scope, output_fn, keep_prob)
    return train_logits, inference_logits

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)`.
# - Process target data using your `process_decoding_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)`.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
#     # TODO: Implement Function
#     enc_input = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, enc_embedding_size)
#     enc_layer = encoding_layer(enc_input, rnn_size, num_layers, keep_prob)
    
#     dec_inputs = process_decoding_input(target_data, target_vocab_to_int, batch_size)
# #     embed_target = tf.contrib.layers.embed_sequence(dec_input, target_vocab_size, dec_embedding_size)
    
#     dec_embed = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size]))
#     dec_embeddings = tf.Variable(tf.truncated_normal([target_vocab_size, dec_embedding_size], stddev=0.01))
#     dec_embed_inputs = tf.nn.embedding_lookup(dec_embeddings, dec_inputs)
    
#     train_logits, inf_logits = decoding_layer(dec_embed_inputs, dec_embed, enc_layer, target_vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)
    
    # Apply embedding to the input data for the encoder
    enc_embed_input = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, enc_embedding_size)
    # Encode the input 
    enc_state = encoding_layer(enc_embed_input, rnn_size, num_layers, keep_prob)
    # Process target data 
    dec_input = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    # Apply embedding to the target data for the decoder.
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    # Decode the encoded input 
    train_logits, infer_logits = decoding_layer(dec_embed_input, dec_embeddings, enc_state, target_vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)
    
    return train_logits, infer_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# target_data Tensor("Placeholder_1:0", shape=(64, 22), dtype=int32)
# target_vocab_to_int {'<EOS>': 1, '<GO>': 3}
# batch_size 64
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability

# %%
# Number of Epochs
epochs = 3
# Batch Size
batch_size = 256
# RNN Size
rnn_size = 128
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 256
decoding_embedding_size = 256
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.8

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)
# Out:
# target_data Tensor("targets:0", shape=(?, ?), dtype=int32)
# target_vocab_to_int {'as-tu': 171, 'pomme': 286, 'conduite': 271, 'jamais': 318, 'je': 293, 'ours': 63, 'pleut': 232, 'des': 201, "n'aimez": 235, 'détestait': 114, 'ne': 183, 'aimés': 15, 'notre': 21, 'rouillée': 224, 'aimait': 69, 'vit': 119, 'en': 139, 'aiment-ils': 36, 'mes': 230, 'préférées': 357, 'douce': 200, 'anglais': 17, 'allions': 7, 'peu': 53, 'voudrait': 83, 'allée': 125, 'aimeraient': 214, 'mois': 59, 'france': 170, 'habituellement': 42, 'tout': 141, "l'éléphant": 289, 'grande': 46, 'été': 195, 'souvent': 122, 'chiens': 279, 'prévois': 74, 'redoutée': 126, 'singe': 313, 'espagnol': 218, 'avril': 82, 'entre': 296, 'dernier': 169, 'automobile': 204, 'à': 312, 'sur': 292, 'lions': 136, 'petits': 191, 'il': 237, 'pluie': 158, 'aimons': 231, 'manguiers': 23, 'brillant': 267, 'mangues': 68, 'légère': 334, "n'a": 37, 'visite': 45, 'voulaient': 161, 'favori': 172, 'agréable': 297, 'nouvelle': 263, 'fruit': 285, 'poire': 104, 'chaud': 142, 'sont': 55, "l'ours": 91, 'fraises': 54, 'chats': 157, 'redoutés': 268, 'pluvieux': 287, 'tranquille': 196, 'comment': 198, 'est-ce': 31, 'mais': 100, 'plaît': 324, 'petit': 186, 'envisagent': 124, 'préféré': 338, 'préférés': 107, 'merveilleux': 166, 't': 48, 'cépage': 295, 'prochain': 339, 'california': 65, 'au': 76, 'inde': 322, 'moins': 308, 'pourquoi': 229, 'cours': 327, 'pourraient': 210, 'états-unis': 179, "l'animal": 284, 'frisquet': 193, 'cher': 354, 'traduction': 282, 'chaude': 19, 'glaciales': 97, 'noir': 239, 'les': 222, 'terrain': 212, '-ce': 30, 'traduire': 22, 'jersey': 207, 'oiseau': 148, 'pommes': 58, 'allés': 154, "n'est": 335, '<UNK>': 2, 'du': 344, 'chevaux': 116, 'chine': 315, 'lion': 66, 'printemps': 317, 'prévoient': 233, "n'aiment": 121, "n'aimons": 345, 'êtes-vous': 174, 'que': 336, 'singes': 52, "l'": 277, 'préférée': 150, 'mangue': 276, 'occupée': 118, "d'": 343, 'généralement': 319, 'petite': 40, 'lui': 185, 'rouge': 168, 'rendre': 152, 'gelés': 299, "l'automobile": 190, 'football': 87, 'est': 192, 'de': 350, 'relaxant': 177, 'neige': 20, 'octobre': 130, 'avons': 149, 'animaux': 253, 'gel': 101, 'bleue': 353, 'citron': 13, 'pêches': 260, 'neigeux': 99, 'requin': 75, 'souris': 244, 'fait': 333, 'pêche': 10, 'portugais': 281, 'et': 89, 'mouillé': 351, 'parfois': 352, 'décembre': 331, 'pluies': 134, 'voulait': 274, "l'épicerie": 106, 'limes': 310, '-il': 265, 'visiter': 182, 'lac': 330, 'veut': 294, '-ils': 92, 'se': 216, "n'êtes": 120, 'va': 173, 'occupé': 307, 'doux': 39, 'vont': 109, 'eiffel': 163, 'mon': 86, 'i': 90, 'bleu': 228, 'automne': 197, 'aux': 346, 'avez': 96, 'prévoyons': 328, 'février': 98, 'brillante': 259, 'septembre': 341, 'cheval': 35, 'temps': 273, 'bien': 349, 'comme': 213, 'nouveau': 300, 'trop': 146, 'vieux': 145, "l'oiseau": 167, 'éléphant': 329, 'vieille': 206, 'étaient': 84, 'détend': 247, 'difficile': 176, 'traduis': 290, 'enneigé': 18, '?': 71, 'juillet': 221, 'où': 234, 'serpents': 79, 'vers': 147, 'rouillé': 254, 'grands': 123, '<GO>': 3, 'trouvé': 323, 'détendre': 88, 'grosse': 11, 'jaune': 203, 'serpent': 288, 'a': 129, 'moindres': 81, 'faire': 33, 'aimé': 108, 'dernière': 245, 'vous': 159, 'froid': 160, 'vu': 44, 'un': 110, 'mouillée': 70, 'pas': 236, 'qui': 56, 'belle': 257, 'elle': 178, ',': 151, 'détestez': 80, 'humide': 95, "j'aime": 225, 'frais': 187, 'sec': 50, 'déteste': 73, 'pousse': 6, 'vais': 113, 'new': 61, 'verte': 138, '<PAD>': 0, 'aimez': 316, 'blanche': 256, 'une': 194, 'tour': 208, 'janvier': 144, 'nos': 227, 'verts': 9, 'cet': 298, 'nous': 240, 'fruits': 162, 'es-tu': 103, 'vos': 238, "n'aime": 135, 'sèche': 342, 'apprécié': 215, 'grosses': 164, 'oiseaux': 38, 'envisage': 325, 'grand': 117, 'son': 49, 'favoris': 165, 'rouille': 28, 'aimé.': 51, 'animal': 220, 'durant': 115, 'paris': 105, 'quand': 306, 'citrons': 302, 'gros': 85, 'pamplemousses': 77, 'blanc': 199, 'veulent': 301, '<EOS>': 1, 'beau': 155, 'aime': 25, 'le': 102, 'votre': 47, "l'orange": 133, 'magnifique': 14, 'leurs': 175, 'poires': 93, 'volant': 269, ...
# batch_size 256

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/538 - Train Accuracy:  0.234, Validation Accuracy:  0.316, Loss:  5.877
# Epoch   0 Batch    1/538 - Train Accuracy:  0.231, Validation Accuracy:  0.316, Loss:  5.687
# Epoch   0 Batch    2/538 - Train Accuracy:  0.252, Validation Accuracy:  0.316, Loss:  5.494
# Epoch   0 Batch    3/538 - Train Accuracy:  0.229, Validation Accuracy:  0.316, Loss:  5.356
# Epoch   0 Batch    4/538 - Train Accuracy:  0.237, Validation Accuracy:  0.316, Loss:  5.166
# Epoch   0 Batch    5/538 - Train Accuracy:  0.263, Validation Accuracy:  0.316, Loss:  4.921
# Epoch   0 Batch    6/538 - Train Accuracy:  0.268, Validation Accuracy:  0.316, Loss:  4.728
# Epoch   0 Batch    7/538 - Train Accuracy:  0.245, Validation Accuracy:  0.316, Loss:  4.659
# Epoch   0 Batch    8/538 - Train Accuracy:  0.255, Validation Accuracy:  0.327, Loss:  4.515
# Epoch   0 Batch    9/538 - Train Accuracy:  0.254, Validation Accuracy:  0.328, Loss:  4.391
# Epoch   0 Batch   10/538 - Train Accuracy:  0.253, Validation Accuracy:  0.341, Loss:  4.371
# Epoch   0 Batch   11/538 - Train Accuracy:  0.270, Validation Accuracy:  0.345, Loss:  4.198
# Epoch   0 Batch   12/538 - Train Accuracy:  0.265, Validation Accuracy:  0.346, Loss:  4.136
# Epoch   0 Batch   13/538 - Train Accuracy:  0.318, Validation Accuracy:  0.346, Loss:  3.791
# Epoch   0 Batch   14/538 - Train Accuracy:  0.274, Validation Accuracy:  0.347, Loss:  3.911
# Epoch   0 Batch   15/538 - Train Accuracy:  0.320, Validation Accuracy:  0.347, Loss:  3.631
# Epoch   0 Batch   16/538 - Train Accuracy:  0.301, Validation Accuracy:  0.348, Loss:  3.594
# Epoch   0 Batch   17/538 - Train Accuracy:  0.287, Validation Accuracy:  0.350, Loss:  3.617
# Epoch   0 Batch   18/538 - Train Accuracy:  0.289, Validation Accuracy:  0.361, Loss:  3.595
# Epoch   0 Batch   19/538 - Train Accuracy:  0.301, Validation Accuracy:  0.377, Loss:  3.539
# Epoch   0 Batch   20/538 - Train Accuracy:  0.336, Validation Accuracy:  0.381, Loss:  3.362
# Epoch   0 Batch   21/538 - Train Accuracy:  0.271, Validation Accuracy:  0.385, Loss:  3.581
# Epoch   0 Batch   22/538 - Train Accuracy:  0.321, Validation Accuracy:  0.385, Loss:  3.362
# Epoch   0 Batch   23/538 - Train Accuracy:  0.325, Validation Accuracy:  0.384, Loss:  3.303
# Epoch   0 Batch   24/538 - Train Accuracy:  0.338, Validation Accuracy:  0.384, Loss:  3.229
# Epoch   0 Batch   25/538 - Train Accuracy:  0.319, Validation Accuracy:  0.378, Loss:  3.275
# Epoch   0 Batch   26/538 - Train Accuracy:  0.320, Validation Accuracy:  0.383, Loss:  3.255
# Epoch   0 Batch   27/538 - Train Accuracy:  0.322, Validation Accuracy:  0.383, Loss:  3.209
# Epoch   0 Batch   28/538 - Train Accuracy:  0.380, Validation Accuracy:  0.384, Loss:  2.936
# Epoch   0 Batch   29/538 - Train Accuracy:  0.343, Validation Accuracy:  0.384, Loss:  3.081
# Epoch   0 Batch   30/538 - Train Accuracy:  0.312, Validation Accuracy:  0.378, Loss:  3.181
# Epoch   0 Batch   31/538 - Train Accuracy:  0.342, Validation Accuracy:  0.378, Loss:  3.020
# Epoch   0 Batch   32/538 - Train Accuracy:  0.322, Validation Accuracy:  0.378, Loss:  3.073
# Epoch   0 Batch   33/538 - Train Accuracy:  0.344, Validation Accuracy:  0.385, Loss:  2.994
# Epoch   0 Batch   34/538 - Train Accuracy:  0.322, Validation Accuracy:  0.380, Loss:  3.077
# Epoch   0 Batch   35/538 - Train Accuracy:  0.308, Validation Accuracy:  0.384, Loss:  3.078
# Epoch   0 Batch   36/538 - Train Accuracy:  0.345, Validation Accuracy:  0.384, Loss:  2.949
# Epoch   0 Batch   37/538 - Train Accuracy:  0.318, Validation Accuracy:  0.384, Loss:  3.011
# Epoch   0 Batch   38/538 - Train Accuracy:  0.319, Validation Accuracy:  0.394, Loss:  3.051
# Epoch   0 Batch   39/538 - Train Accuracy:  0.330, Validation Accuracy:  0.398, Loss:  3.027
# Epoch   0 Batch   40/538 - Train Accuracy:  0.385, Validation Accuracy:  0.393, Loss:  2.743
# Epoch   0 Batch   41/538 - Train Accuracy:  0.330, Validation Accuracy:  0.399, Loss:  2.975
# Epoch   0 Batch   42/538 - Train Accuracy:  0.337, Validation Accuracy:  0.400, Loss:  2.934
# Epoch   0 Batch   43/538 - Train Accuracy:  0.339, Validation Accuracy:  0.398, Loss:  2.957
# Epoch   0 Batch   44/538 - Train Accuracy:  0.326, Validation Accuracy:  0.400, Loss:  2.972
# Epoch   0 Batch   45/538 - Train Accuracy:  0.379, Validation Accuracy:  0.407, Loss:  2.801
# Epoch   0 Batch   46/538 - Train Accuracy:  0.344, Validation Accuracy:  0.407, Loss:  2.910
# Epoch   0 Batch   47/538 - Train Accuracy:  0.386, Validation Accuracy:  0.418, Loss:  2.776
# Epoch   0 Batch   48/538 - Train Accuracy:  0.408, Validation Accuracy:  0.426, Loss:  2.735
# Epoch   0 Batch   49/538 - Train Accuracy:  0.350, Validation Accuracy:  0.425, Loss:  2.935
# Epoch   0 Batch   50/538 - Train Accuracy:  0.369, Validation Accuracy:  0.431, Loss:  2.834
# Epoch   0 Batch   51/538 - Train Accuracy:  0.322, Validation Accuracy:  0.433, Loss:  3.053
# Epoch   0 Batch   52/538 - Train Accuracy:  0.374, Validation Accuracy:  0.422, Loss:  2.828
# Epoch   0 Batch   53/538 - Train Accuracy:  0.415, Validation Accuracy:  0.426, Loss:  2.637
# Epoch   0 Batch   54/538 - Train Accuracy:  0.381, Validation Accuracy:  0.431, Loss:  2.797
# Epoch   0 Batch   55/538 - Train Accuracy:  0.361, Validation Accuracy:  0.432, Loss:  2.855
# Epoch   0 Batch   56/538 - Train Accuracy:  0.379, Validation Accuracy:  0.420, Loss:  2.719
# Epoch   0 Batch   57/538 - Train Accuracy:  0.355, Validation Accuracy:  0.437, Loss:  2.867
# Epoch   0 Batch   58/538 - Train Accuracy:  0.350, Validation Accuracy:  0.434, Loss:  2.848
# Epoch   0 Batch   59/538 - Train Accuracy:  0.356, Validation Accuracy:  0.427, Loss:  2.820
# Epoch   0 Batch   60/538 - Train Accuracy:  0.369, Validation Accuracy:  0.435, Loss:  2.777
# Epoch   0 Batch   61/538 - Train Accuracy:  0.371, Validation Accuracy:  0.432, Loss:  2.744
# Epoch   0 Batch   62/538 - Train Accuracy:  0.390, Validation Accuracy:  0.439, Loss:  2.708
# Epoch   0 Batch   63/538 - Train Accuracy:  0.404, Validation Accuracy:  0.433, Loss:  2.604
# Epoch   0 Batch   64/538 - Train Accuracy:  0.410, Validation Accuracy:  0.439, Loss:  2.625
# Epoch   0 Batch   65/538 - Train Accuracy:  0.362, Validation Accuracy:  0.429, Loss:  2.771
# Epoch   0 Batch   66/538 - Train Accuracy:  0.408, Validation Accuracy:  0.442, Loss:  2.624
# Epoch   0 Batch   67/538 - Train Accuracy:  0.390, Validation Accuracy:  0.441, Loss:  2.662
# Epoch   0 Batch   68/538 - Train Accuracy:  0.403, Validation Accuracy:  0.441, Loss:  2.567
# Epoch   0 Batch   69/538 - Train Accuracy:  0.379, Validation Accuracy:  0.442, Loss:  2.693
# Epoch   0 Batch   70/538 - Train Accuracy:  0.411, Validation Accuracy:  0.452, Loss:  2.579
# Epoch   0 Batch   71/538 - Train Accuracy:  0.394, Validation Accuracy:  0.453, Loss:  2.666
# Epoch   0 Batch   72/538 - Train Accuracy:  0.415, Validation Accuracy:  0.446, Loss:  2.548
# Epoch   0 Batch   73/538 - Train Accuracy:  0.385, Validation Accuracy:  0.452, Loss:  2.667
# Epoch   0 Batch   74/538 - Train Accuracy:  0.427, Validation Accuracy:  0.455, Loss:  2.548
# Epoch   0 Batch   75/538 - Train Accuracy:  0.435, Validation Accuracy:  0.455, Loss:  2.520
# Epoch   0 Batch   76/538 - Train Accuracy:  0.396, Validation Accuracy:  0.460, Loss:  2.678
# Epoch   0 Batch   77/538 - Train Accuracy:  0.394, Validation Accuracy:  0.456, Loss:  2.633
# Epoch   0 Batch   78/538 - Train Accuracy:  0.430, Validation Accuracy:  0.459, Loss:  2.535
# Epoch   0 Batch   79/538 - Train Accuracy:  0.422, Validation Accuracy:  0.463, Loss:  2.491
# Epoch   0 Batch   80/538 - Train Accuracy:  0.386, Validation Accuracy:  0.454, Loss:  2.634
# Epoch   0 Batch   81/538 - Train Accuracy:  0.400, Validation Accuracy:  0.465, Loss:  2.630
# Epoch   0 Batch   82/538 - Train Accuracy:  0.398, Validation Accuracy:  0.456, Loss:  2.563
# Epoch   0 Batch   83/538 - Train Accuracy:  0.411, Validation Accuracy:  0.468, Loss:  2.606
# Epoch   0 Batch   84/538 - Train Accuracy:  0.430, Validation Accuracy:  0.464, Loss:  2.488
# Epoch   0 Batch   85/538 - Train Accuracy:  0.444, Validation Accuracy:  0.458, Loss:  2.377
# Epoch   0 Batch   86/538 - Train Accuracy:  0.416, Validation Accuracy:  0.472, Loss:  2.586
# Epoch   0 Batch   87/538 - Train Accuracy:  0.402, Validation Accuracy:  0.456, Loss:  2.533
# Epoch   0 Batch   88/538 - Train Accuracy:  0.422, Validation Accuracy:  0.475, Loss:  2.537
# Epoch   0 Batch   89/538 - Train Accuracy:  0.428, Validation Accuracy:  0.471, Loss:  2.523
# Epoch   0 Batch   90/538 - Train Accuracy:  0.438, Validation Accuracy:  0.467, Loss:  2.436
# Epoch   0 Batch   91/538 - Train Accuracy:  0.409, Validation Accuracy:  0.470, Loss:  2.557
# Epoch   0 Batch   92/538 - Train Accuracy:  0.411, Validation Accuracy:  0.453, Loss:  2.510
# Epoch   0 Batch   93/538 - Train Accuracy:  0.418, Validation Accuracy:  0.479, Loss:  2.549
# Epoch   0 Batch   94/538 - Train Accuracy:  0.418, Validation Accuracy:  0.479, Loss:  2.564
# Epoch   0 Batch   95/538 - Train Accuracy:  0.456, Validation Accuracy:  0.466, Loss:  2.309
# Epoch   0 Batch   96/538 - Train Accuracy:  0.453, Validation Accuracy:  0.474, Loss:  2.334
# Epoch   0 Batch   97/538 - Train Accuracy:  0.411, Validation Accuracy:  0.472, Loss:  2.482
# Epoch   0 Batch   98/538 - Train Accuracy:  0.454, Validation Accuracy:  0.474, Loss:  2.308
# Epoch   0 Batch   99/538 - Train Accuracy:  0.423, Validation Accuracy:  0.482, Loss:  2.480
# Epoch   0 Batch  100/538 - Train Accuracy:  0.436, Validation Accuracy:  0.484, Loss:  2.429
# Epoch   0 Batch  101/538 - Train Accuracy:  0.437, Validation Accuracy:  0.483, Loss:  2.416
# Epoch   0 Batch  102/538 - Train Accuracy:  0.433, Validation Accuracy:  0.481, Loss:  2.463
# Epoch   0 Batch  103/538 - Train Accuracy:  0.438, Validation Accuracy:  0.475, Loss:  2.381
# Epoch   0 Batch  104/538 - Train Accuracy:  0.454, Validation Accuracy:  0.482, Loss:  2.359
# Epoch   0 Batch  105/538 - Train Accuracy:  0.457, Validation Accuracy:  0.483, Loss:  2.304
# Epoch   0 Batch  106/538 - Train Accuracy:  0.429, Validation Accuracy:  0.482, Loss:  2.395
# Epoch   0 Batch  107/538 - Train Accuracy:  0.427, Validation Accuracy:  0.488, Loss:  2.429
# Epoch   0 Batch  108/538 - Train Accuracy:  0.452, Validation Accuracy:  0.484, Loss:  2.373
# Epoch   0 Batch  109/538 - Train Accuracy:  0.445, Validation Accuracy:  0.487, Loss:  2.365
# Epoch   0 Batch  110/538 - Train Accuracy:  0.432, Validation Accuracy:  0.485, Loss:  2.399
# Epoch   0 Batch  111/538 - Train Accuracy:  0.464, Validation Accuracy:  0.484, Loss:  2.274
# Epoch   0 Batch  112/538 - Train Accuracy:  0.426, Validation Accuracy:  0.486, Loss:  2.366
# Epoch   0 Batch  113/538 - Train Accuracy:  0.426, Validation Accuracy:  0.482, Loss:  2.376
# Epoch   0 Batch  114/538 - Train Accuracy:  0.462, Validation Accuracy:  0.480, Loss:  2.220
# Epoch   0 Batch  115/538 - Train Accuracy:  0.437, Validation Accuracy:  0.483, Loss:  2.337
# Epoch   0 Batch  116/538 - Train Accuracy:  0.459, Validation Accuracy:  0.481, Loss:  2.256
# Epoch   0 Batch  117/538 - Train Accuracy:  0.469, Validation Accuracy:  0.494, Loss:  2.220
# Epoch   0 Batch  118/538 - Train Accuracy:  0.462, Validation Accuracy:  0.487, Loss:  2.213
# Epoch   0 Batch  119/538 - Train Accuracy:  0.462, Validation Accuracy:  0.489, Loss:  2.180
# Epoch   0 Batch  120/538 - Train Accuracy:  0.439, Validation Accuracy:  0.495, Loss:  2.272
# Epoch   0 Batch  121/538 - Train Accuracy:  0.469, Validation Accuracy:  0.490, Loss:  2.159
# Epoch   0 Batch  122/538 - Train Accuracy:  0.464, Validation Accuracy:  0.494, Loss:  2.182
# Epoch   0 Batch  123/538 - Train Accuracy:  0.475, Validation Accuracy:  0.490, Loss:  2.134
# Epoch   0 Batch  124/538 - Train Accuracy:  0.483, Validation Accuracy:  0.499, Loss:  2.088
# Epoch   0 Batch  125/538 - Train Accuracy:  0.464, Validation Accuracy:  0.498, Loss:  2.168
# Epoch   0 Batch  126/538 - Train Accuracy:  0.490, Validation Accuracy:  0.502, Loss:  2.086
# Epoch   0 Batch  127/538 - Train Accuracy:  0.450, Validation Accuracy:  0.494, Loss:  2.253
# Epoch   0 Batch  128/538 - Train Accuracy:  0.471, Validation Accuracy:  0.498, Loss:  2.113
# Epoch   0 Batch  129/538 - Train Accuracy:  0.472, Validation Accuracy:  0.499, Loss:  2.115
# Epoch   0 Batch  130/538 - Train Accuracy:  0.464, Validation Accuracy:  0.503, Loss:  2.136
# Epoch   0 Batch  131/538 - Train Accuracy:  0.441, Validation Accuracy:  0.483, Loss:  2.218
# Epoch   0 Batch  132/538 - Train Accuracy:  0.469, Validation Accuracy:  0.491, Loss:  2.099
# Epoch   0 Batch  133/538 - Train Accuracy:  0.485, Validation Accuracy:  0.496, Loss:  2.064
# Epoch   0 Batch  134/538 - Train Accuracy:  0.435, Validation Accuracy:  0.503, Loss:  2.251
# Epoch   0 Batch  135/538 - Train Accuracy:  0.466, Validation Accuracy:  0.502, Loss:  2.092
# Epoch   0 Batch  136/538 - Train Accuracy:  0.455, Validation Accuracy:  0.498, Loss:  2.120
# Epoch   0 Batch  137/538 - Train Accuracy:  0.474, Validation Accuracy:  0.497, Loss:  2.079
# Epoch   0 Batch  138/538 - Train Accuracy:  0.479, Validation Accuracy:  0.504, Loss:  2.083
# Epoch   0 Batch  139/538 - Train Accuracy:  0.444, Validation Accuracy:  0.496, Loss:  2.225
# Epoch   0 Batch  140/538 - Train Accuracy:  0.457, Validation Accuracy:  0.511, Loss:  2.191
# Epoch   0 Batch  141/538 - Train Accuracy:  0.470, Validation Accuracy:  0.513, Loss:  2.160
# Epoch   0 Batch  142/538 - Train Accuracy:  0.501, Validation Accuracy:  0.515, Loss:  1.997
# Epoch   0 Batch  143/538 - Train Accuracy:  0.462, Validation Accuracy:  0.518, Loss:  2.156
# Epoch   0 Batch  144/538 - Train Accuracy:  0.475, Validation Accuracy:  0.514, Loss:  2.104
# Epoch   0 Batch  145/538 - Train Accuracy:  0.483, Validation Accuracy:  0.506, Loss:  2.043
# Epoch   0 Batch  146/538 - Train Accuracy:  0.493, Validation Accuracy:  0.513, Loss:  1.960
# Epoch   0 Batch  147/538 - Train Accuracy:  0.501, Validation Accuracy:  0.517, Loss:  1.980
# Epoch   0 Batch  148/538 - Train Accuracy:  0.459, Validation Accuracy:  0.508, Loss:  2.134
# Epoch   0 Batch  149/538 - Train Accuracy:  0.445, Validation Accuracy:  0.497, Loss:  2.066
# Epoch   0 Batch  150/538 - Train Accuracy:  0.470, Validation Accuracy:  0.508, Loss:  2.076
# Epoch   0 Batch  151/538 - Train Accuracy:  0.480, Validation Accuracy:  0.515, Loss:  1.985
# Epoch   0 Batch  152/538 - Train Accuracy:  0.462, Validation Accuracy:  0.496, Loss:  1.969
# Epoch   0 Batch  153/538 - Train Accuracy:  0.469, Validation Accuracy:  0.522, Loss:  2.071
# Epoch   0 Batch  154/538 - Train Accuracy:  0.483, Validation Accuracy:  0.517, Loss:  1.996
# Epoch   0 Batch  155/538 - Train Accuracy:  0.486, Validation Accuracy:  0.504, Loss:  1.958
# Epoch   0 Batch  156/538 - Train Accuracy:  0.455, Validation Accuracy:  0.502, Loss:  2.060
# Epoch   0 Batch  157/538 - Train Accuracy:  0.478, Validation Accuracy:  0.513, Loss:  1.976
# Epoch   0 Batch  158/538 - Train Accuracy:  0.464, Validation Accuracy:  0.511, Loss:  2.061
# Epoch   0 Batch  159/538 - Train Accuracy:  0.472, Validation Accuracy:  0.513, Loss:  2.049
# Epoch   0 Batch  160/538 - Train Accuracy:  0.483, Validation Accuracy:  0.519, Loss:  1.949
# Epoch   0 Batch  161/538 - Train Accuracy:  0.468, Validation Accuracy:  0.516, Loss:  2.001
# Epoch   0 Batch  162/538 - Train Accuracy:  0.495, Validation Accuracy:  0.511, Loss:  1.895
# Epoch   0 Batch  163/538 - Train Accuracy:  0.495, Validation Accuracy:  0.518, Loss:  1.962
# Epoch   0 Batch  164/538 - Train Accuracy:  0.470, Validation Accuracy:  0.518, Loss:  2.022
# Epoch   0 Batch  165/538 - Train Accuracy:  0.506, Validation Accuracy:  0.526, Loss:  1.858
# Epoch   0 Batch  166/538 - Train Accuracy:  0.496, Validation Accuracy:  0.526, Loss:  1.976
# Epoch   0 Batch  167/538 - Train Accuracy:  0.495, Validation Accuracy:  0.519, Loss:  1.859
# Epoch   0 Batch  168/538 - Train Accuracy:  0.465, Validation Accuracy:  0.513, Loss:  1.988
# Epoch   0 Batch  169/538 - Train Accuracy:  0.474, Validation Accuracy:  0.513, Loss:  1.944
# Epoch   0 Batch  170/538 - Train Accuracy:  0.478, Validation Accuracy:  0.507, Loss:  1.898
# Epoch   0 Batch  171/538 - Train Accuracy:  0.477, Validation Accuracy:  0.520, Loss:  1.995
# Epoch   0 Batch  172/538 - Train Accuracy:  0.478, Validation Accuracy:  0.515, Loss:  1.891
# Epoch   0 Batch  173/538 - Train Accuracy:  0.485, Validation Accuracy:  0.517, Loss:  1.873
# Epoch   0 Batch  174/538 - Train Accuracy:  0.447, Validation Accuracy:  0.515, Loss:  1.992
# Epoch   0 Batch  175/538 - Train Accuracy:  0.441, Validation Accuracy:  0.515, Loss:  2.008
# Epoch   0 Batch  176/538 - Train Accuracy:  0.470, Validation Accuracy:  0.521, Loss:  1.973
# Epoch   0 Batch  177/538 - Train Accuracy:  0.489, Validation Accuracy:  0.521, Loss:  1.884
# Epoch   0 Batch  178/538 - Train Accuracy:  0.508, Validation Accuracy:  0.518, Loss:  1.796
# Epoch   0 Batch  179/538 - Train Accuracy:  0.475, Validation Accuracy:  0.525, Loss:  1.909
# Epoch   0 Batch  180/538 - Train Accuracy:  0.507, Validation Accuracy:  0.522, Loss:  1.847
# Epoch   0 Batch  181/538 - Train Accuracy:  0.446, Validation Accuracy:  0.514, Loss:  1.950
# Epoch   0 Batch  182/538 - Train Accuracy:  0.436, Validation Accuracy:  0.505, Loss:  1.932
# Epoch   0 Batch  183/538 - Train Accuracy:  0.483, Validation Accuracy:  0.497, Loss:  1.818
# Epoch   0 Batch  184/538 - Train Accuracy:  0.486, Validation Accuracy:  0.506, Loss:  1.815
# Epoch   0 Batch  185/538 - Train Accuracy:  0.455, Validation Accuracy:  0.502, Loss:  1.878
# Epoch   0 Batch  186/538 - Train Accuracy:  0.477, Validation Accuracy:  0.508, Loss:  1.845
# Epoch   0 Batch  187/538 - Train Accuracy:  0.503, Validation Accuracy:  0.506, Loss:  1.754
# Epoch   0 Batch  188/538 - Train Accuracy:  0.444, Validation Accuracy:  0.501, Loss:  1.889
# Epoch   0 Batch  189/538 - Train Accuracy:  0.457, Validation Accuracy:  0.502, Loss:  1.865
# Epoch   0 Batch  190/538 - Train Accuracy:  0.485, Validation Accuracy:  0.508, Loss:  1.834
# Epoch   0 Batch  191/538 - Train Accuracy:  0.482, Validation Accuracy:  0.502, Loss:  1.781
# Epoch   0 Batch  192/538 - Train Accuracy:  0.482, Validation Accuracy:  0.514, Loss:  1.791
# Epoch   0 Batch  193/538 - Train Accuracy:  0.495, Validation Accuracy:  0.509, Loss:  1.752
# Epoch   0 Batch  194/538 - Train Accuracy:  0.441, Validation Accuracy:  0.505, Loss:  1.875
# Epoch   0 Batch  195/538 - Train Accuracy:  0.491, Validation Accuracy:  0.507, Loss:  1.749
# Epoch   0 Batch  196/538 - Train Accuracy:  0.475, Validation Accuracy:  0.504, Loss:  1.795
# Epoch   0 Batch  197/538 - Train Accuracy:  0.471, Validation Accuracy:  0.493, Loss:  1.744
# Epoch   0 Batch  198/538 - Train Accuracy:  0.516, Validation Accuracy:  0.513, Loss:  1.751
# Epoch   0 Batch  199/538 - Train Accuracy:  0.465, Validation Accuracy:  0.507, Loss:  1.883
# Epoch   0 Batch  200/538 - Train Accuracy:  0.467, Validation Accuracy:  0.507, Loss:  1.824
# Epoch   0 Batch  201/538 - Train Accuracy:  0.498, Validation Accuracy:  0.509, Loss:  1.719
# Epoch   0 Batch  202/538 - Train Accuracy:  0.464, Validation Accuracy:  0.520, Loss:  1.872
# Epoch   0 Batch  203/538 - Train Accuracy:  0.482, Validation Accuracy:  0.533, Loss:  1.846
# Epoch   0 Batch  204/538 - Train Accuracy:  0.476, Validation Accuracy:  0.531, Loss:  1.807
# Epoch   0 Batch  205/538 - Train Accuracy:  0.505, Validation Accuracy:  0.522, Loss:  1.700
# Epoch   0 Batch  206/538 - Train Accuracy:  0.467, Validation Accuracy:  0.520, Loss:  1.811
# Epoch   0 Batch  207/538 - Train Accuracy:  0.510, Validation Accuracy:  0.526, Loss:  1.704
# Epoch   0 Batch  208/538 - Train Accuracy:  0.472, Validation Accuracy:  0.524, Loss:  1.780
# Epoch   0 Batch  209/538 - Train Accuracy:  0.472, Validation Accuracy:  0.528, Loss:  1.805
# Epoch   0 Batch  210/538 - Train Accuracy:  0.500, Validation Accuracy:  0.530, Loss:  1.719
# Epoch   0 Batch  211/538 - Train Accuracy:  0.471, Validation Accuracy:  0.528, Loss:  1.797
# Epoch   0 Batch  212/538 - Train Accuracy:  0.499, Validation Accuracy:  0.520, Loss:  1.713
# Epoch   0 Batch  213/538 - Train Accuracy:  0.495, Validation Accuracy:  0.530, Loss:  1.721
# Epoch   0 Batch  214/538 - Train Accuracy:  0.483, Validation Accuracy:  0.533, Loss:  1.754
# Epoch   0 Batch  215/538 - Train Accuracy:  0.483, Validation Accuracy:  0.529, Loss:  1.764
# Epoch   0 Batch  216/538 - Train Accuracy:  0.462, Validation Accuracy:  0.525, Loss:  1.786
# Epoch   0 Batch  217/538 - Train Accuracy:  0.509, Validation Accuracy:  0.520, Loss:  1.677
# Epoch   0 Batch  218/538 - Train Accuracy:  0.470, Validation Accuracy:  0.522, Loss:  1.735
# Epoch   0 Batch  219/538 - Train Accuracy:  0.477, Validation Accuracy:  0.534, Loss:  1.771
# Epoch   0 Batch  220/538 - Train Accuracy:  0.490, Validation Accuracy:  0.536, Loss:  1.669
# Epoch   0 Batch  221/538 - Train Accuracy:  0.506, Validation Accuracy:  0.531, Loss:  1.678
# Epoch   0 Batch  222/538 - Train Accuracy:  0.500, Validation Accuracy:  0.522, Loss:  1.630
# Epoch   0 Batch  223/538 - Train Accuracy:  0.474, Validation Accuracy:  0.523, Loss:  1.746
# Epoch   0 Batch  224/538 - Train Accuracy:  0.471, Validation Accuracy:  0.524, Loss:  1.761
# Epoch   0 Batch  225/538 - Train Accuracy:  0.512, Validation Accuracy:  0.533, Loss:  1.631
# Epoch   0 Batch  226/538 - Train Accuracy:  0.516, Validation Accuracy:  0.535, Loss:  1.632
# Epoch   0 Batch  227/538 - Train Accuracy:  0.536, Validation Accuracy:  0.540, Loss:  1.564
# Epoch   0 Batch  228/538 - Train Accuracy:  0.491, Validation Accuracy:  0.536, Loss:  1.635
# Epoch   0 Batch  229/538 - Train Accuracy:  0.504, Validation Accuracy:  0.536, Loss:  1.636
# Epoch   0 Batch  230/538 - Train Accuracy:  0.492, Validation Accuracy:  0.538, Loss:  1.693
# Epoch   0 Batch  231/538 - Train Accuracy:  0.483, Validation Accuracy:  0.534, Loss:  1.665
# Epoch   0 Batch  232/538 - Train Accuracy:  0.487, Validation Accuracy:  0.533, Loss:  1.688
# Epoch   0 Batch  233/538 - Train Accuracy:  0.520, Validation Accuracy:  0.533, Loss:  1.625
# Epoch   0 Batch  234/538 - Train Accuracy:  0.472, Validation Accuracy:  0.530, Loss:  1.685
# Epoch   0 Batch  235/538 - Train Accuracy:  0.509, Validation Accuracy:  0.535, Loss:  1.626
# Epoch   0 Batch  236/538 - Train Accuracy:  0.465, Validation Accuracy:  0.524, Loss:  1.680
# Epoch   0 Batch  237/538 - Train Accuracy:  0.499, Validation Accuracy:  0.529, Loss:  1.614
# Epoch   0 Batch  238/538 - Train Accuracy:  0.530, Validation Accuracy:  0.534, Loss:  1.564
# Epoch   0 Batch  239/538 - Train Accuracy:  0.501, Validation Accuracy:  0.536, Loss:  1.666
# Epoch   0 Batch  240/538 - Train Accuracy:  0.494, Validation Accuracy:  0.537, Loss:  1.655
# Epoch   0 Batch  241/538 - Train Accuracy:  0.487, Validation Accuracy:  0.536, Loss:  1.655
# Epoch   0 Batch  242/538 - Train Accuracy:  0.496, Validation Accuracy:  0.534, Loss:  1.643
# Epoch   0 Batch  243/538 - Train Accuracy:  0.466, Validation Accuracy:  0.527, Loss:  1.712
# Epoch   0 Batch  244/538 - Train Accuracy:  0.501, Validation Accuracy:  0.525, Loss:  1.591
# Epoch   0 Batch  245/538 - Train Accuracy:  0.471, Validation Accuracy:  0.520, Loss:  1.637
# Epoch   0 Batch  246/538 - Train Accuracy:  0.515, Validation Accuracy:  0.532, Loss:  1.541
# Epoch   0 Batch  247/538 - Train Accuracy:  0.479, Validation Accuracy:  0.536, Loss:  1.655
# Epoch   0 Batch  248/538 - Train Accuracy:  0.488, Validation Accuracy:  0.532, Loss:  1.616
# Epoch   0 Batch  249/538 - Train Accuracy:  0.495, Validation Accuracy:  0.528, Loss:  1.538
# Epoch   0 Batch  250/538 - Train Accuracy:  0.477, Validation Accuracy:  0.521, Loss:  1.601
# Epoch   0 Batch  251/538 - Train Accuracy:  0.467, Validation Accuracy:  0.515, Loss:  1.606
# Epoch   0 Batch  252/538 - Train Accuracy:  0.495, Validation Accuracy:  0.524, Loss:  1.518
# Epoch   0 Batch  253/538 - Train Accuracy:  0.502, Validation Accuracy:  0.531, Loss:  1.522
# Epoch   0 Batch  254/538 - Train Accuracy:  0.486, Validation Accuracy:  0.522, Loss:  1.579
# Epoch   0 Batch  255/538 - Train Accuracy:  0.487, Validation Accuracy:  0.532, Loss:  1.606
# Epoch   0 Batch  256/538 - Train Accuracy:  0.478, Validation Accuracy:  0.532, Loss:  1.598
# Epoch   0 Batch  257/538 - Train Accuracy:  0.506, Validation Accuracy:  0.529, Loss:  1.524
# Epoch   0 Batch  258/538 - Train Accuracy:  0.512, Validation Accuracy:  0.531, Loss:  1.499
# Epoch   0 Batch  259/538 - Train Accuracy:  0.505, Validation Accuracy:  0.528, Loss:  1.519
# Epoch   0 Batch  260/538 - Train Accuracy:  0.497, Validation Accuracy:  0.528, Loss:  1.536
# Epoch   0 Batch  261/538 - Train Accuracy:  0.477, Validation Accuracy:  0.531, Loss:  1.601
# Epoch   0 Batch  262/538 - Train Accuracy:  0.479, Validation Accuracy:  0.525, Loss:  1.614
# Epoch   0 Batch  263/538 - Train Accuracy:  0.497, Validation Accuracy:  0.524, Loss:  1.561
# Epoch   0 Batch  264/538 - Train Accuracy:  0.489, Validation Accuracy:  0.537, Loss:  1.560
# Epoch   0 Batch  265/538 - Train Accuracy:  0.461, Validation Accuracy:  0.523, Loss:  1.586
# Epoch   0 Batch  266/538 - Train Accuracy:  0.508, Validation Accuracy:  0.525, Loss:  1.506
# Epoch   0 Batch  267/538 - Train Accuracy:  0.482, Validation Accuracy:  0.532, Loss:  1.546
# Epoch   0 Batch  268/538 - Train Accuracy:  0.495, Validation Accuracy:  0.529, Loss:  1.477
# Epoch   0 Batch  269/538 - Train Accuracy:  0.477, Validation Accuracy:  0.537, Loss:  1.525
# Epoch   0 Batch  270/538 - Train Accuracy:  0.483, Validation Accuracy:  0.540, Loss:  1.551
# Epoch   0 Batch  271/538 - Train Accuracy:  0.462, Validation Accuracy:  0.523, Loss:  1.551
# Epoch   0 Batch  272/538 - Train Accuracy:  0.480, Validation Accuracy:  0.540, Loss:  1.614
# Epoch   0 Batch  273/538 - Train Accuracy:  0.473, Validation Accuracy:  0.518, Loss:  1.532
# Epoch   0 Batch  274/538 - Train Accuracy:  0.461, Validation Accuracy:  0.536, Loss:  1.580
# Epoch   0 Batch  275/538 - Train Accuracy:  0.491, Validation Accuracy:  0.540, Loss:  1.541
# Epoch   0 Batch  276/538 - Train Accuracy:  0.475, Validation Accuracy:  0.519, Loss:  1.520
# Epoch   0 Batch  277/538 - Train Accuracy:  0.486, Validation Accuracy:  0.533, Loss:  1.499
# Epoch   0 Batch  278/538 - Train Accuracy:  0.493, Validation Accuracy:  0.537, Loss:  1.482
# Epoch   0 Batch  279/538 - Train Accuracy:  0.476, Validation Accuracy:  0.520, Loss:  1.485
# Epoch   0 Batch  280/538 - Train Accuracy:  0.531, Validation Accuracy:  0.542, Loss:  1.426
# Epoch   0 Batch  281/538 - Train Accuracy:  0.484, Validation Accuracy:  0.527, Loss:  1.506
# Epoch   0 Batch  282/538 - Train Accuracy:  0.480, Validation Accuracy:  0.511, Loss:  1.449
# Epoch   0 Batch  283/538 - Train Accuracy:  0.492, Validation Accuracy:  0.530, Loss:  1.452
# Epoch   0 Batch  284/538 - Train Accuracy:  0.487, Validation Accuracy:  0.525, Loss:  1.470
# Epoch   0 Batch  285/538 - Train Accuracy:  0.507, Validation Accuracy:  0.523, Loss:  1.403
# Epoch   0 Batch  286/538 - Train Accuracy:  0.494, Validation Accuracy:  0.540, Loss:  1.482
# Epoch   0 Batch  287/538 - Train Accuracy:  0.492, Validation Accuracy:  0.513, Loss:  1.418
# Epoch   0 Batch  288/538 - Train Accuracy:  0.457, Validation Accuracy:  0.517, Loss:  1.494
# Epoch   0 Batch  289/538 - Train Accuracy:  0.525, Validation Accuracy:  0.536, Loss:  1.381
# Epoch   0 Batch  290/538 - Train Accuracy:  0.450, Validation Accuracy:  0.511, Loss:  1.480
# Epoch   0 Batch  291/538 - Train Accuracy:  0.482, Validation Accuracy:  0.528, Loss:  1.430
# Epoch   0 Batch  292/538 - Train Accuracy:  0.513, Validation Accuracy:  0.540, Loss:  1.374
# Epoch   0 Batch  293/538 - Train Accuracy:  0.495, Validation Accuracy:  0.520, Loss:  1.400
# Epoch   0 Batch  294/538 - Train Accuracy:  0.438, Validation Accuracy:  0.514, Loss:  1.511
# Epoch   0 Batch  295/538 - Train Accuracy:  0.536, Validation Accuracy:  0.537, Loss:  1.335
# Epoch   0 Batch  296/538 - Train Accuracy:  0.480, Validation Accuracy:  0.513, Loss:  1.394
# Epoch   0 Batch  297/538 - Train Accuracy:  0.443, Validation Accuracy:  0.520, Loss:  1.492
# Epoch   0 Batch  298/538 - Train Accuracy:  0.514, Validation Accuracy:  0.544, Loss:  1.416
# Epoch   0 Batch  299/538 - Train Accuracy:  0.492, Validation Accuracy:  0.526, Loss:  1.396
# Epoch   0 Batch  300/538 - Train Accuracy:  0.490, Validation Accuracy:  0.504, Loss:  1.344
# Epoch   0 Batch  301/538 - Train Accuracy:  0.493, Validation Accuracy:  0.538, Loss:  1.417
# Epoch   0 Batch  302/538 - Train Accuracy:  0.518, Validation Accuracy:  0.533, Loss:  1.342
# Epoch   0 Batch  303/538 - Train Accuracy:  0.506, Validation Accuracy:  0.503, Loss:  1.313
# Epoch   0 Batch  304/538 - Train Accuracy:  0.484, Validation Accuracy:  0.539, Loss:  1.431
# Epoch   0 Batch  305/538 - Train Accuracy:  0.496, Validation Accuracy:  0.537, Loss:  1.361
# Epoch   0 Batch  306/538 - Train Accuracy:  0.484, Validation Accuracy:  0.514, Loss:  1.363
# Epoch   0 Batch  307/538 - Train Accuracy:  0.498, Validation Accuracy:  0.542, Loss:  1.380
# Epoch   0 Batch  308/538 - Train Accuracy:  0.496, Validation Accuracy:  0.531, Loss:  1.363
# Epoch   0 Batch  309/538 - Train Accuracy:  0.462, Validation Accuracy:  0.523, Loss:  1.417
# Epoch   0 Batch  310/538 - Train Accuracy:  0.497, Validation Accuracy:  0.536, Loss:  1.400
# Epoch   0 Batch  311/538 - Train Accuracy:  0.504, Validation Accuracy:  0.527, Loss:  1.325
# Epoch   0 Batch  312/538 - Train Accuracy:  0.525, Validation Accuracy:  0.527, Loss:  1.260
# Epoch   0 Batch  313/538 - Train Accuracy:  0.489, Validation Accuracy:  0.532, Loss:  1.379
# Epoch   0 Batch  314/538 - Train Accuracy:  0.492, Validation Accuracy:  0.529, Loss:  1.349
# Epoch   0 Batch  315/538 - Train Accuracy:  0.509, Validation Accuracy:  0.530, Loss:  1.328
# Epoch   0 Batch  316/538 - Train Accuracy:  0.511, Validation Accuracy:  0.538, Loss:  1.319
# Epoch   0 Batch  317/538 - Train Accuracy:  0.494, Validation Accuracy:  0.529, Loss:  1.357
# Epoch   0 Batch  318/538 - Train Accuracy:  0.497, Validation Accuracy:  0.533, Loss:  1.314
# Epoch   0 Batch  319/538 - Train Accuracy:  0.510, Validation Accuracy:  0.537, Loss:  1.308
# Epoch   0 Batch  320/538 - Train Accuracy:  0.504, Validation Accuracy:  0.535, Loss:  1.315
# Epoch   0 Batch  321/538 - Train Accuracy:  0.503, Validation Accuracy:  0.520, Loss:  1.285
# Epoch   0 Batch  322/538 - Train Accuracy:  0.507, Validation Accuracy:  0.537, Loss:  1.341
# Epoch   0 Batch  323/538 - Train Accuracy:  0.506, Validation Accuracy:  0.545, Loss:  1.310
# Epoch   0 Batch  324/538 - Train Accuracy:  0.481, Validation Accuracy:  0.530, Loss:  1.384
# Epoch   0 Batch  325/538 - Train Accuracy:  0.493, Validation Accuracy:  0.524, Loss:  1.313
# Epoch   0 Batch  326/538 - Train Accuracy:  0.492, Validation Accuracy:  0.530, Loss:  1.320
# Epoch   0 Batch  327/538 - Train Accuracy:  0.495, Validation Accuracy:  0.533, Loss:  1.346
# Epoch   0 Batch  328/538 - Train Accuracy:  0.518, Validation Accuracy:  0.531, Loss:  1.269
# Epoch   0 Batch  329/538 - Train Accuracy:  0.504, Validation Accuracy:  0.521, Loss:  1.297
# Epoch   0 Batch  330/538 - Train Accuracy:  0.511, Validation Accuracy:  0.529, Loss:  1.267
# Epoch   0 Batch  331/538 - Train Accuracy:  0.476, Validation Accuracy:  0.529, Loss:  1.308
# Epoch   0 Batch  332/538 - Train Accuracy:  0.487, Validation Accuracy:  0.539, Loss:  1.323
# Epoch   0 Batch  333/538 - Train Accuracy:  0.522, Validation Accuracy:  0.544, Loss:  1.262
# Epoch   0 Batch  334/538 - Train Accuracy:  0.540, Validation Accuracy:  0.531, Loss:  1.190
# Epoch   0 Batch  335/538 - Train Accuracy:  0.524, Validation Accuracy:  0.539, Loss:  1.252
# Epoch   0 Batch  336/538 - Train Accuracy:  0.517, Validation Accuracy:  0.540, Loss:  1.265
# Epoch   0 Batch  337/538 - Train Accuracy:  0.497, Validation Accuracy:  0.517, Loss:  1.267
# Epoch   0 Batch  338/538 - Train Accuracy:  0.509, Validation Accuracy:  0.537, Loss:  1.281
# Epoch   0 Batch  339/538 - Train Accuracy:  0.513, Validation Accuracy:  0.534, Loss:  1.252
# Epoch   0 Batch  340/538 - Train Accuracy:  0.469, Validation Accuracy:  0.527, Loss:  1.314
# Epoch   0 Batch  341/538 - Train Accuracy:  0.494, Validation Accuracy:  0.538, Loss:  1.297
# Epoch   0 Batch  342/538 - Train Accuracy:  0.517, Validation Accuracy:  0.536, Loss:  1.252
# Epoch   0 Batch  343/538 - Train Accuracy:  0.509, Validation Accuracy:  0.534, Loss:  1.288
# Epoch   0 Batch  344/538 - Train Accuracy:  0.490, Validation Accuracy:  0.534, Loss:  1.273
# Epoch   0 Batch  345/538 - Train Accuracy:  0.523, Validation Accuracy:  0.528, Loss:  1.219
# Epoch   0 Batch  346/538 - Train Accuracy:  0.508, Validation Accuracy:  0.539, Loss:  1.268
# Epoch   0 Batch  347/538 - Train Accuracy:  0.501, Validation Accuracy:  0.539, Loss:  1.276
# Epoch   0 Batch  348/538 - Train Accuracy:  0.500, Validation Accuracy:  0.540, Loss:  1.237
# Epoch   0 Batch  349/538 - Train Accuracy:  0.469, Validation Accuracy:  0.526, Loss:  1.254
# Epoch   0 Batch  350/538 - Train Accuracy:  0.517, Validation Accuracy:  0.537, Loss:  1.253
# Epoch   0 Batch  351/538 - Train Accuracy:  0.487, Validation Accuracy:  0.536, Loss:  1.314
# Epoch   0 Batch  352/538 - Train Accuracy:  0.528, Validation Accuracy:  0.543, Loss:  1.214
# Epoch   0 Batch  353/538 - Train Accuracy:  0.488, Validation Accuracy:  0.522, Loss:  1.265
# Epoch   0 Batch  354/538 - Train Accuracy:  0.474, Validation Accuracy:  0.520, Loss:  1.290
# Epoch   0 Batch  355/538 - Train Accuracy:  0.505, Validation Accuracy:  0.545, Loss:  1.288
# Epoch   0 Batch  356/538 - Train Accuracy:  0.537, Validation Accuracy:  0.547, Loss:  1.176
# Epoch   0 Batch  357/538 - Train Accuracy:  0.494, Validation Accuracy:  0.523, Loss:  1.249
# Epoch   0 Batch  358/538 - Train Accuracy:  0.506, Validation Accuracy:  0.545, Loss:  1.235
# Epoch   0 Batch  359/538 - Train Accuracy:  0.525, Validation Accuracy:  0.548, Loss:  1.190
# Epoch   0 Batch  360/538 - Train Accuracy:  0.488, Validation Accuracy:  0.540, Loss:  1.259
# Epoch   0 Batch  361/538 - Train Accuracy:  0.514, Validation Accuracy:  0.536, Loss:  1.197
# Epoch   0 Batch  362/538 - Train Accuracy:  0.543, Validation Accuracy:  0.556, Loss:  1.162
# Epoch   0 Batch  363/538 - Train Accuracy:  0.528, Validation Accuracy:  0.544, Loss:  1.180
# Epoch   0 Batch  364/538 - Train Accuracy:  0.472, Validation Accuracy:  0.526, Loss:  1.249
# Epoch   0 Batch  365/538 - Train Accuracy:  0.530, Validation Accuracy:  0.558, Loss:  1.219
# Epoch   0 Batch  366/538 - Train Accuracy:  0.528, Validation Accuracy:  0.549, Loss:  1.233
# Epoch   0 Batch  367/538 - Train Accuracy:  0.497, Validation Accuracy:  0.541, Loss:  1.206
# Epoch   0 Batch  368/538 - Train Accuracy:  0.584, Validation Accuracy:  0.548, Loss:  1.038
# Epoch   0 Batch  369/538 - Train Accuracy:  0.528, Validation Accuracy:  0.562, Loss:  1.198
# Epoch   0 Batch  370/538 - Train Accuracy:  0.499, Validation Accuracy:  0.541, Loss:  1.233
# Epoch   0 Batch  371/538 - Train Accuracy:  0.516, Validation Accuracy:  0.533, Loss:  1.163
# Epoch   0 Batch  372/538 - Train Accuracy:  0.517, Validation Accuracy:  0.549, Loss:  1.194
# Epoch   0 Batch  373/538 - Train Accuracy:  0.499, Validation Accuracy:  0.548, Loss:  1.194
# Epoch   0 Batch  374/538 - Train Accuracy:  0.494, Validation Accuracy:  0.539, Loss:  1.216
# Epoch   0 Batch  375/538 - Train Accuracy:  0.530, Validation Accuracy:  0.547, Loss:  1.116
# Epoch   0 Batch  376/538 - Train Accuracy:  0.518, Validation Accuracy:  0.563, Loss:  1.192
# Epoch   0 Batch  377/538 - Train Accuracy:  0.531, Validation Accuracy:  0.562, Loss:  1.161
# Epoch   0 Batch  378/538 - Train Accuracy:  0.532, Validation Accuracy:  0.546, Loss:  1.118
# Epoch   0 Batch  379/538 - Train Accuracy:  0.545, Validation Accuracy:  0.562, Loss:  1.147
# Epoch   0 Batch  380/538 - Train Accuracy:  0.521, Validation Accuracy:  0.560, Loss:  1.175
# Epoch   0 Batch  381/538 - Train Accuracy:  0.522, Validation Accuracy:  0.558, Loss:  1.122
# Epoch   0 Batch  382/538 - Train Accuracy:  0.530, Validation Accuracy:  0.570, Loss:  1.173
# Epoch   0 Batch  383/538 - Train Accuracy:  0.526, Validation Accuracy:  0.570, Loss:  1.164
# Epoch   0 Batch  384/538 - Train Accuracy:  0.533, Validation Accuracy:  0.551, Loss:  1.153
# Epoch   0 Batch  385/538 - Train Accuracy:  0.544, Validation Accuracy:  0.561, Loss:  1.143
# Epoch   0 Batch  386/538 - Train Accuracy:  0.522, Validation Accuracy:  0.556, Loss:  1.174
# Epoch   0 Batch  387/538 - Train Accuracy:  0.504, Validation Accuracy:  0.540, Loss:  1.178
# Epoch   0 Batch  388/538 - Train Accuracy:  0.539, Validation Accuracy:  0.556, Loss:  1.124
# Epoch   0 Batch  389/538 - Train Accuracy:  0.506, Validation Accuracy:  0.558, Loss:  1.197
# Epoch   0 Batch  390/538 - Train Accuracy:  0.538, Validation Accuracy:  0.541, Loss:  1.105
# Epoch   0 Batch  391/538 - Train Accuracy:  0.525, Validation Accuracy:  0.540, Loss:  1.130
# Epoch   0 Batch  392/538 - Train Accuracy:  0.526, Validation Accuracy:  0.562, Loss:  1.126
# Epoch   0 Batch  393/538 - Train Accuracy:  0.551, Validation Accuracy:  0.569, Loss:  1.072
# Epoch   0 Batch  394/538 - Train Accuracy:  0.480, Validation Accuracy:  0.545, Loss:  1.181
# Epoch   0 Batch  395/538 - Train Accuracy:  0.504, Validation Accuracy:  0.547, Loss:  1.167
# Epoch   0 Batch  396/538 - Train Accuracy:  0.513, Validation Accuracy:  0.565, Loss:  1.130
# Epoch   0 Batch  397/538 - Train Accuracy:  0.504, Validation Accuracy:  0.557, Loss:  1.187
# Epoch   0 Batch  398/538 - Train Accuracy:  0.506, Validation Accuracy:  0.550, Loss:  1.147
# Epoch   0 Batch  399/538 - Train Accuracy:  0.489, Validation Accuracy:  0.557, Loss:  1.174
# Epoch   0 Batch  400/538 - Train Accuracy:  0.533, Validation Accuracy:  0.567, Loss:  1.113
# Epoch   0 Batch  401/538 - Train Accuracy:  0.510, Validation Accuracy:  0.560, Loss:  1.137
# Epoch   0 Batch  402/538 - Train Accuracy:  0.535, Validation Accuracy:  0.559, Loss:  1.104
# Epoch   0 Batch  403/538 - Train Accuracy:  0.521, Validation Accuracy:  0.564, Loss:  1.148
# Epoch   0 Batch  404/538 - Train Accuracy:  0.551, Validation Accuracy:  0.565, Loss:  1.068
# Epoch   0 Batch  405/538 - Train Accuracy:  0.531, Validation Accuracy:  0.560, Loss:  1.076
# Epoch   0 Batch  406/538 - Train Accuracy:  0.549, Validation Accuracy:  0.569, Loss:  1.084
# Epoch   0 Batch  407/538 - Train Accuracy:  0.536, Validation Accuracy:  0.561, Loss:  1.082
# Epoch   0 Batch  408/538 - Train Accuracy:  0.506, Validation Accuracy:  0.570, Loss:  1.164
# Epoch   0 Batch  409/538 - Train Accuracy:  0.511, Validation Accuracy:  0.562, Loss:  1.112
# Epoch   0 Batch  410/538 - Train Accuracy:  0.529, Validation Accuracy:  0.562, Loss:  1.086
# Epoch   0 Batch  411/538 - Train Accuracy:  0.537, Validation Accuracy:  0.573, Loss:  1.060
# Epoch   0 Batch  412/538 - Train Accuracy:  0.549, Validation Accuracy:  0.573, Loss:  1.037
# Epoch   0 Batch  413/538 - Train Accuracy:  0.531, Validation Accuracy:  0.575, Loss:  1.127
# Epoch   0 Batch  414/538 - Train Accuracy:  0.529, Validation Accuracy:  0.565, Loss:  1.105
# Epoch   0 Batch  415/538 - Train Accuracy:  0.525, Validation Accuracy:  0.574, Loss:  1.097
# Epoch   0 Batch  416/538 - Train Accuracy:  0.592, Validation Accuracy:  0.581, Loss:  1.012
# Epoch   0 Batch  417/538 - Train Accuracy:  0.527, Validation Accuracy:  0.572, Loss:  1.103
# Epoch   0 Batch  418/538 - Train Accuracy:  0.525, Validation Accuracy:  0.571, Loss:  1.104
# Epoch   0 Batch  419/538 - Train Accuracy:  0.558, Validation Accuracy:  0.579, Loss:  1.058
# Epoch   0 Batch  420/538 - Train Accuracy:  0.544, Validation Accuracy:  0.576, Loss:  1.064
# Epoch   0 Batch  421/538 - Train Accuracy:  0.545, Validation Accuracy:  0.568, Loss:  1.042
# Epoch   0 Batch  422/538 - Train Accuracy:  0.547, Validation Accuracy:  0.562, Loss:  1.049
# Epoch   0 Batch  423/538 - Train Accuracy:  0.549, Validation Accuracy:  0.569, Loss:  1.064
# Epoch   0 Batch  424/538 - Train Accuracy:  0.539, Validation Accuracy:  0.578, Loss:  1.045
# Epoch   0 Batch  425/538 - Train Accuracy:  0.557, Validation Accuracy:  0.576, Loss:  1.013
# Epoch   0 Batch  426/538 - Train Accuracy:  0.530, Validation Accuracy:  0.554, Loss:  1.029
# Epoch   0 Batch  427/538 - Train Accuracy:  0.537, Validation Accuracy:  0.579, Loss:  1.053
# Epoch   0 Batch  428/538 - Train Accuracy:  0.564, Validation Accuracy:  0.578, Loss:  1.000
# Epoch   0 Batch  429/538 - Train Accuracy:  0.540, Validation Accuracy:  0.558, Loss:  1.017
# Epoch   0 Batch  430/538 - Train Accuracy:  0.531, Validation Accuracy:  0.554, Loss:  1.029
# Epoch   0 Batch  431/538 - Train Accuracy:  0.549, Validation Accuracy:  0.586, Loss:  1.028
# Epoch   0 Batch  432/538 - Train Accuracy:  0.586, Validation Accuracy:  0.579, Loss:  0.956
# Epoch   0 Batch  433/538 - Train Accuracy:  0.521, Validation Accuracy:  0.575, Loss:  1.069
# Epoch   0 Batch  434/538 - Train Accuracy:  0.517, Validation Accuracy:  0.573, Loss:  1.079
# Epoch   0 Batch  435/538 - Train Accuracy:  0.546, Validation Accuracy:  0.579, Loss:  1.020
# Epoch   0 Batch  436/538 - Train Accuracy:  0.521, Validation Accuracy:  0.574, Loss:  1.052
# Epoch   0 Batch  437/538 - Train Accuracy:  0.525, Validation Accuracy:  0.578, Loss:  1.054
# Epoch   0 Batch  438/538 - Train Accuracy:  0.563, Validation Accuracy:  0.578, Loss:  1.014
# Epoch   0 Batch  439/538 - Train Accuracy:  0.571, Validation Accuracy:  0.582, Loss:  0.986
# Epoch   0 Batch  440/538 - Train Accuracy:  0.524, Validation Accuracy:  0.563, Loss:  1.051
# Epoch   0 Batch  441/538 - Train Accuracy:  0.519, Validation Accuracy:  0.567, Loss:  1.056
# Epoch   0 Batch  442/538 - Train Accuracy:  0.567, Validation Accuracy:  0.566, Loss:  0.919
# Epoch   0 Batch  443/538 - Train Accuracy:  0.560, Validation Accuracy:  0.570, Loss:  1.000
# Epoch   0 Batch  444/538 - Train Accuracy:  0.593, Validation Accuracy:  0.570, Loss:  0.933
# Epoch   0 Batch  445/538 - Train Accuracy:  0.558, Validation Accuracy:  0.573, Loss:  0.976
# Epoch   0 Batch  446/538 - Train Accuracy:  0.574, Validation Accuracy:  0.574, Loss:  0.935
# Epoch   0 Batch  447/538 - Train Accuracy:  0.534, Validation Accuracy:  0.578, Loss:  1.002
# Epoch   0 Batch  448/538 - Train Accuracy:  0.582, Validation Accuracy:  0.575, Loss:  0.920
# Epoch   0 Batch  449/538 - Train Accuracy:  0.545, Validation Accuracy:  0.577, Loss:  1.024
# Epoch   0 Batch  450/538 - Train Accuracy:  0.571, Validation Accuracy:  0.580, Loss:  0.989
# Epoch   0 Batch  451/538 - Train Accuracy:  0.545, Validation Accuracy:  0.585, Loss:  0.993
# Epoch   0 Batch  452/538 - Train Accuracy:  0.554, Validation Accuracy:  0.593, Loss:  0.982
# Epoch   0 Batch  453/538 - Train Accuracy:  0.545, Validation Accuracy:  0.580, Loss:  0.998
# Epoch   0 Batch  454/538 - Train Accuracy:  0.555, Validation Accuracy:  0.584, Loss:  0.956
# Epoch   0 Batch  455/538 - Train Accuracy:  0.570, Validation Accuracy:  0.582, Loss:  0.904
# Epoch   0 Batch  456/538 - Train Accuracy:  0.638, Validation Accuracy:  0.589, Loss:  0.843
# Epoch   0 Batch  457/538 - Train Accuracy:  0.522, Validation Accuracy:  0.580, Loss:  1.002
# Epoch   0 Batch  458/538 - Train Accuracy:  0.551, Validation Accuracy:  0.592, Loss:  0.955
# Epoch   0 Batch  459/538 - Train Accuracy:  0.576, Validation Accuracy:  0.586, Loss:  0.959
# Epoch   0 Batch  460/538 - Train Accuracy:  0.535, Validation Accuracy:  0.587, Loss:  0.957
# Epoch   0 Batch  461/538 - Train Accuracy:  0.506, Validation Accuracy:  0.578, Loss:  1.033
# Epoch   0 Batch  462/538 - Train Accuracy:  0.550, Validation Accuracy:  0.583, Loss:  0.956
# Epoch   0 Batch  463/538 - Train Accuracy:  0.551, Validation Accuracy:  0.594, Loss:  0.977
# Epoch   0 Batch  464/538 - Train Accuracy:  0.556, Validation Accuracy:  0.595, Loss:  0.984
# Epoch   0 Batch  465/538 - Train Accuracy:  0.550, Validation Accuracy:  0.586, Loss:  0.963
# Epoch   0 Batch  466/538 - Train Accuracy:  0.544, Validation Accuracy:  0.585, Loss:  0.972
# Epoch   0 Batch  467/538 - Train Accuracy:  0.559, Validation Accuracy:  0.584, Loss:  0.932
# Epoch   0 Batch  468/538 - Train Accuracy:  0.584, Validation Accuracy:  0.585, Loss:  0.981
# Epoch   0 Batch  469/538 - Train Accuracy:  0.545, Validation Accuracy:  0.571, Loss:  0.982
# Epoch   0 Batch  470/538 - Train Accuracy:  0.568, Validation Accuracy:  0.569, Loss:  0.923
# Epoch   0 Batch  471/538 - Train Accuracy:  0.556, Validation Accuracy:  0.578, Loss:  0.931
# Epoch   0 Batch  472/538 - Train Accuracy:  0.554, Validation Accuracy:  0.585, Loss:  0.943
# Epoch   0 Batch  473/538 - Train Accuracy:  0.523, Validation Accuracy:  0.585, Loss:  0.966
# Epoch   0 Batch  474/538 - Train Accuracy:  0.580, Validation Accuracy:  0.585, Loss:  0.901
# Epoch   0 Batch  475/538 - Train Accuracy:  0.587, Validation Accuracy:  0.589, Loss:  0.900
# Epoch   0 Batch  476/538 - Train Accuracy:  0.544, Validation Accuracy:  0.584, Loss:  0.956
# Epoch   0 Batch  477/538 - Train Accuracy:  0.559, Validation Accuracy:  0.579, Loss:  0.946
# Epoch   0 Batch  478/538 - Train Accuracy:  0.581, Validation Accuracy:  0.583, Loss:  0.906
# Epoch   0 Batch  479/538 - Train Accuracy:  0.593, Validation Accuracy:  0.586, Loss:  0.881
# Epoch   0 Batch  480/538 - Train Accuracy:  0.590, Validation Accuracy:  0.588, Loss:  0.902
# Epoch   0 Batch  481/538 - Train Accuracy:  0.564, Validation Accuracy:  0.586, Loss:  0.914
# Epoch   0 Batch  482/538 - Train Accuracy:  0.594, Validation Accuracy:  0.589, Loss:  0.833
# Epoch   0 Batch  483/538 - Train Accuracy:  0.542, Validation Accuracy:  0.580, Loss:  0.932
# Epoch   0 Batch  484/538 - Train Accuracy:  0.594, Validation Accuracy:  0.581, Loss:  0.909
# Epoch   0 Batch  485/538 - Train Accuracy:  0.573, Validation Accuracy:  0.588, Loss:  0.901
# Epoch   0 Batch  486/538 - Train Accuracy:  0.578, Validation Accuracy:  0.591, Loss:  0.879
# Epoch   0 Batch  487/538 - Train Accuracy:  0.581, Validation Accuracy:  0.598, Loss:  0.876
# Epoch   0 Batch  488/538 - Train Accuracy:  0.616, Validation Accuracy:  0.594, Loss:  0.885
# Epoch   0 Batch  489/538 - Train Accuracy:  0.566, Validation Accuracy:  0.594, Loss:  0.929
# Epoch   0 Batch  490/538 - Train Accuracy:  0.575, Validation Accuracy:  0.594, Loss:  0.877
# Epoch   0 Batch  491/538 - Train Accuracy:  0.560, Validation Accuracy:  0.596, Loss:  0.929
# Epoch   0 Batch  492/538 - Train Accuracy:  0.584, Validation Accuracy:  0.595, Loss:  0.925
# Epoch   0 Batch  493/538 - Train Accuracy:  0.549, Validation Accuracy:  0.593, Loss:  0.887
# Epoch   0 Batch  494/538 - Train Accuracy:  0.568, Validation Accuracy:  0.591, Loss:  0.932
# Epoch   0 Batch  495/538 - Train Accuracy:  0.562, Validation Accuracy:  0.594, Loss:  0.913
# Epoch   0 Batch  496/538 - Train Accuracy:  0.566, Validation Accuracy:  0.587, Loss:  0.909
# Epoch   0 Batch  497/538 - Train Accuracy:  0.571, Validation Accuracy:  0.590, Loss:  0.884
# Epoch   0 Batch  498/538 - Train Accuracy:  0.562, Validation Accuracy:  0.595, Loss:  0.894
# Epoch   0 Batch  499/538 - Train Accuracy:  0.602, Validation Accuracy:  0.595, Loss:  0.867
# Epoch   0 Batch  500/538 - Train Accuracy:  0.593, Validation Accuracy:  0.588, Loss:  0.833
# Epoch   0 Batch  501/538 - Train Accuracy:  0.579, Validation Accuracy:  0.585, Loss:  0.893
# Epoch   0 Batch  502/538 - Train Accuracy:  0.554, Validation Accuracy:  0.586, Loss:  0.890
# Epoch   0 Batch  503/538 - Train Accuracy:  0.600, Validation Accuracy:  0.590, Loss:  0.849
# Epoch   0 Batch  504/538 - Train Accuracy:  0.588, Validation Accuracy:  0.594, Loss:  0.889
# Epoch   0 Batch  505/538 - Train Accuracy:  0.589, Validation Accuracy:  0.586, Loss:  0.875
# Epoch   0 Batch  506/538 - Train Accuracy:  0.600, Validation Accuracy:  0.585, Loss:  0.862
# Epoch   0 Batch  507/538 - Train Accuracy:  0.568, Validation Accuracy:  0.589, Loss:  0.889
# Epoch   0 Batch  508/538 - Train Accuracy:  0.590, Validation Accuracy:  0.588, Loss:  0.831
# Epoch   0 Batch  509/538 - Train Accuracy:  0.573, Validation Accuracy:  0.597, Loss:  0.879
# Epoch   0 Batch  510/538 - Train Accuracy:  0.600, Validation Accuracy:  0.599, Loss:  0.850
# Epoch   0 Batch  511/538 - Train Accuracy:  0.607, Validation Accuracy:  0.596, Loss:  0.822
# Epoch   0 Batch  512/538 - Train Accuracy:  0.597, Validation Accuracy:  0.581, Loss:  0.840
# Epoch   0 Batch  513/538 - Train Accuracy:  0.565, Validation Accuracy:  0.586, Loss:  0.874
# Epoch   0 Batch  514/538 - Train Accuracy:  0.568, Validation Accuracy:  0.591, Loss:  0.887
# Epoch   0 Batch  515/538 - Train Accuracy:  0.585, Validation Accuracy:  0.593, Loss:  0.849
# ...
# Epoch   1 Batch  330/538 - Train Accuracy:  0.680, Validation Accuracy:  0.667, Loss:  0.516
# Epoch   1 Batch  331/538 - Train Accuracy:  0.684, Validation Accuracy:  0.669, Loss:  0.523
# Epoch   1 Batch  332/538 - Train Accuracy:  0.659, Validation Accuracy:  0.672, Loss:  0.547
# Epoch   1 Batch  333/538 - Train Accuracy:  0.666, Validation Accuracy:  0.663, Loss:  0.519
# Epoch   1 Batch  334/538 - Train Accuracy:  0.704, Validation Accuracy:  0.671, Loss:  0.493
# Epoch   1 Batch  335/538 - Train Accuracy:  0.679, Validation Accuracy:  0.669, Loss:  0.524
# Epoch   1 Batch  336/538 - Train Accuracy:  0.682, Validation Accuracy:  0.675, Loss:  0.520
# Epoch   1 Batch  337/538 - Train Accuracy:  0.696, Validation Accuracy:  0.671, Loss:  0.519
# Epoch   1 Batch  338/538 - Train Accuracy:  0.635, Validation Accuracy:  0.671, Loss:  0.529
# Epoch   1 Batch  339/538 - Train Accuracy:  0.697, Validation Accuracy:  0.667, Loss:  0.510
# Epoch   1 Batch  340/538 - Train Accuracy:  0.679, Validation Accuracy:  0.668, Loss:  0.552
# Epoch   1 Batch  341/538 - Train Accuracy:  0.656, Validation Accuracy:  0.669, Loss:  0.528
# Epoch   1 Batch  342/538 - Train Accuracy:  0.676, Validation Accuracy:  0.665, Loss:  0.515
# Epoch   1 Batch  343/538 - Train Accuracy:  0.677, Validation Accuracy:  0.668, Loss:  0.549
# Epoch   1 Batch  344/538 - Train Accuracy:  0.666, Validation Accuracy:  0.664, Loss:  0.528
# Epoch   1 Batch  345/538 - Train Accuracy:  0.681, Validation Accuracy:  0.678, Loss:  0.515
# Epoch   1 Batch  346/538 - Train Accuracy:  0.680, Validation Accuracy:  0.678, Loss:  0.533
# Epoch   1 Batch  347/538 - Train Accuracy:  0.672, Validation Accuracy:  0.670, Loss:  0.532
# Epoch   1 Batch  348/538 - Train Accuracy:  0.654, Validation Accuracy:  0.666, Loss:  0.501
# Epoch   1 Batch  349/538 - Train Accuracy:  0.659, Validation Accuracy:  0.671, Loss:  0.528
# Epoch   1 Batch  350/538 - Train Accuracy:  0.669, Validation Accuracy:  0.662, Loss:  0.530
# Epoch   1 Batch  351/538 - Train Accuracy:  0.671, Validation Accuracy:  0.680, Loss:  0.550
# Epoch   1 Batch  352/538 - Train Accuracy:  0.689, Validation Accuracy:  0.674, Loss:  0.524
# Epoch   1 Batch  353/538 - Train Accuracy:  0.684, Validation Accuracy:  0.680, Loss:  0.542
# Epoch   1 Batch  354/538 - Train Accuracy:  0.655, Validation Accuracy:  0.692, Loss:  0.551
# Epoch   1 Batch  355/538 - Train Accuracy:  0.677, Validation Accuracy:  0.691, Loss:  0.539
# Epoch   1 Batch  356/538 - Train Accuracy:  0.695, Validation Accuracy:  0.677, Loss:  0.480
# Epoch   1 Batch  357/538 - Train Accuracy:  0.684, Validation Accuracy:  0.675, Loss:  0.517
# Epoch   1 Batch  358/538 - Train Accuracy:  0.659, Validation Accuracy:  0.680, Loss:  0.515
# Epoch   1 Batch  359/538 - Train Accuracy:  0.685, Validation Accuracy:  0.677, Loss:  0.508
# Epoch   1 Batch  360/538 - Train Accuracy:  0.645, Validation Accuracy:  0.673, Loss:  0.531
# Epoch   1 Batch  361/538 - Train Accuracy:  0.694, Validation Accuracy:  0.671, Loss:  0.505
# Epoch   1 Batch  362/538 - Train Accuracy:  0.683, Validation Accuracy:  0.675, Loss:  0.491
# Epoch   1 Batch  363/538 - Train Accuracy:  0.670, Validation Accuracy:  0.673, Loss:  0.496
# Epoch   1 Batch  364/538 - Train Accuracy:  0.673, Validation Accuracy:  0.689, Loss:  0.549
# Epoch   1 Batch  365/538 - Train Accuracy:  0.689, Validation Accuracy:  0.671, Loss:  0.507
# Epoch   1 Batch  366/538 - Train Accuracy:  0.681, Validation Accuracy:  0.673, Loss:  0.524
# Epoch   1 Batch  367/538 - Train Accuracy:  0.692, Validation Accuracy:  0.683, Loss:  0.503
# Epoch   1 Batch  368/538 - Train Accuracy:  0.722, Validation Accuracy:  0.678, Loss:  0.463
# Epoch   1 Batch  369/538 - Train Accuracy:  0.671, Validation Accuracy:  0.667, Loss:  0.510
# Epoch   1 Batch  370/538 - Train Accuracy:  0.675, Validation Accuracy:  0.680, Loss:  0.531
# Epoch   1 Batch  371/538 - Train Accuracy:  0.683, Validation Accuracy:  0.686, Loss:  0.504
# Epoch   1 Batch  372/538 - Train Accuracy:  0.703, Validation Accuracy:  0.677, Loss:  0.515
# Epoch   1 Batch  373/538 - Train Accuracy:  0.691, Validation Accuracy:  0.678, Loss:  0.503
# Epoch   1 Batch  374/538 - Train Accuracy:  0.672, Validation Accuracy:  0.690, Loss:  0.525
# Epoch   1 Batch  375/538 - Train Accuracy:  0.686, Validation Accuracy:  0.666, Loss:  0.482
# Epoch   1 Batch  376/538 - Train Accuracy:  0.676, Validation Accuracy:  0.674, Loss:  0.520
# Epoch   1 Batch  377/538 - Train Accuracy:  0.679, Validation Accuracy:  0.686, Loss:  0.510
# Epoch   1 Batch  378/538 - Train Accuracy:  0.703, Validation Accuracy:  0.687, Loss:  0.484
# Epoch   1 Batch  379/538 - Train Accuracy:  0.694, Validation Accuracy:  0.680, Loss:  0.487
# Epoch   1 Batch  380/538 - Train Accuracy:  0.682, Validation Accuracy:  0.688, Loss:  0.506
# Epoch   1 Batch  381/538 - Train Accuracy:  0.704, Validation Accuracy:  0.691, Loss:  0.474
# Epoch   1 Batch  382/538 - Train Accuracy:  0.668, Validation Accuracy:  0.691, Loss:  0.510
# Epoch   1 Batch  383/538 - Train Accuracy:  0.678, Validation Accuracy:  0.681, Loss:  0.512
# Epoch   1 Batch  384/538 - Train Accuracy:  0.713, Validation Accuracy:  0.690, Loss:  0.486
# Epoch   1 Batch  385/538 - Train Accuracy:  0.691, Validation Accuracy:  0.675, Loss:  0.496
# Epoch   1 Batch  386/538 - Train Accuracy:  0.676, Validation Accuracy:  0.676, Loss:  0.518
# Epoch   1 Batch  387/538 - Train Accuracy:  0.691, Validation Accuracy:  0.699, Loss:  0.500
# Epoch   1 Batch  388/538 - Train Accuracy:  0.698, Validation Accuracy:  0.681, Loss:  0.489
# Epoch   1 Batch  389/538 - Train Accuracy:  0.669, Validation Accuracy:  0.678, Loss:  0.525
# Epoch   1 Batch  390/538 - Train Accuracy:  0.716, Validation Accuracy:  0.686, Loss:  0.485
# Epoch   1 Batch  391/538 - Train Accuracy:  0.694, Validation Accuracy:  0.679, Loss:  0.493
# Epoch   1 Batch  392/538 - Train Accuracy:  0.661, Validation Accuracy:  0.669, Loss:  0.486
# Epoch   1 Batch  393/538 - Train Accuracy:  0.709, Validation Accuracy:  0.682, Loss:  0.478
# Epoch   1 Batch  394/538 - Train Accuracy:  0.638, Validation Accuracy:  0.683, Loss:  0.517
# Epoch   1 Batch  395/538 - Train Accuracy:  0.654, Validation Accuracy:  0.682, Loss:  0.520
# Epoch   1 Batch  396/538 - Train Accuracy:  0.669, Validation Accuracy:  0.680, Loss:  0.493
# Epoch   1 Batch  397/538 - Train Accuracy:  0.661, Validation Accuracy:  0.686, Loss:  0.515
# Epoch   1 Batch  398/538 - Train Accuracy:  0.692, Validation Accuracy:  0.678, Loss:  0.507
# Epoch   1 Batch  399/538 - Train Accuracy:  0.662, Validation Accuracy:  0.681, Loss:  0.523
# Epoch   1 Batch  400/538 - Train Accuracy:  0.692, Validation Accuracy:  0.682, Loss:  0.489
# Epoch   1 Batch  401/538 - Train Accuracy:  0.684, Validation Accuracy:  0.684, Loss:  0.509
# Epoch   1 Batch  402/538 - Train Accuracy:  0.698, Validation Accuracy:  0.691, Loss:  0.488
# Epoch   1 Batch  403/538 - Train Accuracy:  0.690, Validation Accuracy:  0.697, Loss:  0.508
# Epoch   1 Batch  404/538 - Train Accuracy:  0.708, Validation Accuracy:  0.700, Loss:  0.482
# Epoch   1 Batch  405/538 - Train Accuracy:  0.697, Validation Accuracy:  0.696, Loss:  0.481
# Epoch   1 Batch  406/538 - Train Accuracy:  0.693, Validation Accuracy:  0.690, Loss:  0.477
# Epoch   1 Batch  407/538 - Train Accuracy:  0.687, Validation Accuracy:  0.685, Loss:  0.498
# Epoch   1 Batch  408/538 - Train Accuracy:  0.679, Validation Accuracy:  0.697, Loss:  0.531
# Epoch   1 Batch  409/538 - Train Accuracy:  0.687, Validation Accuracy:  0.696, Loss:  0.513
# Epoch   1 Batch  410/538 - Train Accuracy:  0.671, Validation Accuracy:  0.680, Loss:  0.499
# Epoch   1 Batch  411/538 - Train Accuracy:  0.711, Validation Accuracy:  0.679, Loss:  0.473
# Epoch   1 Batch  412/538 - Train Accuracy:  0.711, Validation Accuracy:  0.689, Loss:  0.471
# Epoch   1 Batch  413/538 - Train Accuracy:  0.687, Validation Accuracy:  0.676, Loss:  0.497
# Epoch   1 Batch  414/538 - Train Accuracy:  0.677, Validation Accuracy:  0.705, Loss:  0.498
# Epoch   1 Batch  415/538 - Train Accuracy:  0.673, Validation Accuracy:  0.710, Loss:  0.497
# Epoch   1 Batch  416/538 - Train Accuracy:  0.697, Validation Accuracy:  0.679, Loss:  0.471
# Epoch   1 Batch  417/538 - Train Accuracy:  0.702, Validation Accuracy:  0.694, Loss:  0.492
# Epoch   1 Batch  418/538 - Train Accuracy:  0.700, Validation Accuracy:  0.702, Loss:  0.500
# Epoch   1 Batch  419/538 - Train Accuracy:  0.706, Validation Accuracy:  0.696, Loss:  0.472
# Epoch   1 Batch  420/538 - Train Accuracy:  0.698, Validation Accuracy:  0.674, Loss:  0.487
# Epoch   1 Batch  421/538 - Train Accuracy:  0.725, Validation Accuracy:  0.697, Loss:  0.464
# Epoch   1 Batch  422/538 - Train Accuracy:  0.710, Validation Accuracy:  0.699, Loss:  0.481
# Epoch   1 Batch  423/538 - Train Accuracy:  0.699, Validation Accuracy:  0.684, Loss:  0.501
# Epoch   1 Batch  424/538 - Train Accuracy:  0.685, Validation Accuracy:  0.701, Loss:  0.484
# Epoch   1 Batch  425/538 - Train Accuracy:  0.704, Validation Accuracy:  0.700, Loss:  0.479
# Epoch   1 Batch  426/538 - Train Accuracy:  0.684, Validation Accuracy:  0.693, Loss:  0.481
# Epoch   1 Batch  427/538 - Train Accuracy:  0.677, Validation Accuracy:  0.695, Loss:  0.498
# Epoch   1 Batch  428/538 - Train Accuracy:  0.718, Validation Accuracy:  0.706, Loss:  0.467
# Epoch   1 Batch  429/538 - Train Accuracy:  0.692, Validation Accuracy:  0.712, Loss:  0.474
# Epoch   1 Batch  430/538 - Train Accuracy:  0.695, Validation Accuracy:  0.682, Loss:  0.482
# Epoch   1 Batch  431/538 - Train Accuracy:  0.696, Validation Accuracy:  0.691, Loss:  0.479
# Epoch   1 Batch  432/538 - Train Accuracy:  0.721, Validation Accuracy:  0.700, Loss:  0.443
# Epoch   1 Batch  433/538 - Train Accuracy:  0.711, Validation Accuracy:  0.706, Loss:  0.503
# Epoch   1 Batch  434/538 - Train Accuracy:  0.647, Validation Accuracy:  0.681, Loss:  0.491
# Epoch   1 Batch  435/538 - Train Accuracy:  0.696, Validation Accuracy:  0.716, Loss:  0.477
# Epoch   1 Batch  436/538 - Train Accuracy:  0.685, Validation Accuracy:  0.696, Loss:  0.489
# Epoch   1 Batch  437/538 - Train Accuracy:  0.691, Validation Accuracy:  0.708, Loss:  0.492
# Epoch   1 Batch  438/538 - Train Accuracy:  0.680, Validation Accuracy:  0.691, Loss:  0.468
# Epoch   1 Batch  439/538 - Train Accuracy:  0.732, Validation Accuracy:  0.708, Loss:  0.458
# Epoch   1 Batch  440/538 - Train Accuracy:  0.699, Validation Accuracy:  0.706, Loss:  0.493
# Epoch   1 Batch  441/538 - Train Accuracy:  0.683, Validation Accuracy:  0.709, Loss:  0.484
# Epoch   1 Batch  442/538 - Train Accuracy:  0.720, Validation Accuracy:  0.695, Loss:  0.432
# Epoch   1 Batch  443/538 - Train Accuracy:  0.726, Validation Accuracy:  0.703, Loss:  0.464
# Epoch   1 Batch  444/538 - Train Accuracy:  0.742, Validation Accuracy:  0.702, Loss:  0.446
# Epoch   1 Batch  445/538 - Train Accuracy:  0.711, Validation Accuracy:  0.700, Loss:  0.457
# Epoch   1 Batch  446/538 - Train Accuracy:  0.727, Validation Accuracy:  0.709, Loss:  0.444
# Epoch   1 Batch  447/538 - Train Accuracy:  0.697, Validation Accuracy:  0.718, Loss:  0.476
# Epoch   1 Batch  448/538 - Train Accuracy:  0.703, Validation Accuracy:  0.716, Loss:  0.448
# Epoch   1 Batch  449/538 - Train Accuracy:  0.696, Validation Accuracy:  0.714, Loss:  0.489
# Epoch   1 Batch  450/538 - Train Accuracy:  0.722, Validation Accuracy:  0.718, Loss:  0.484
# Epoch   1 Batch  451/538 - Train Accuracy:  0.715, Validation Accuracy:  0.710, Loss:  0.468
# Epoch   1 Batch  452/538 - Train Accuracy:  0.710, Validation Accuracy:  0.715, Loss:  0.455
# Epoch   1 Batch  453/538 - Train Accuracy:  0.710, Validation Accuracy:  0.711, Loss:  0.467
# Epoch   1 Batch  454/538 - Train Accuracy:  0.710, Validation Accuracy:  0.712, Loss:  0.460
# Epoch   1 Batch  455/538 - Train Accuracy:  0.725, Validation Accuracy:  0.707, Loss:  0.428
# Epoch   1 Batch  456/538 - Train Accuracy:  0.747, Validation Accuracy:  0.701, Loss:  0.418
# Epoch   1 Batch  457/538 - Train Accuracy:  0.692, Validation Accuracy:  0.713, Loss:  0.486
# Epoch   1 Batch  458/538 - Train Accuracy:  0.719, Validation Accuracy:  0.710, Loss:  0.442
# Epoch   1 Batch  459/538 - Train Accuracy:  0.712, Validation Accuracy:  0.716, Loss:  0.457
# Epoch   1 Batch  460/538 - Train Accuracy:  0.689, Validation Accuracy:  0.715, Loss:  0.450
# Epoch   1 Batch  461/538 - Train Accuracy:  0.700, Validation Accuracy:  0.719, Loss:  0.487
# Epoch   1 Batch  462/538 - Train Accuracy:  0.728, Validation Accuracy:  0.727, Loss:  0.456
# Epoch   1 Batch  463/538 - Train Accuracy:  0.702, Validation Accuracy:  0.717, Loss:  0.475
# Epoch   1 Batch  464/538 - Train Accuracy:  0.739, Validation Accuracy:  0.719, Loss:  0.469
# Epoch   1 Batch  465/538 - Train Accuracy:  0.702, Validation Accuracy:  0.716, Loss:  0.467
# Epoch   1 Batch  466/538 - Train Accuracy:  0.723, Validation Accuracy:  0.713, Loss:  0.463
# Epoch   1 Batch  467/538 - Train Accuracy:  0.731, Validation Accuracy:  0.712, Loss:  0.457
# Epoch   1 Batch  468/538 - Train Accuracy:  0.744, Validation Accuracy:  0.722, Loss:  0.474
# Epoch   1 Batch  469/538 - Train Accuracy:  0.714, Validation Accuracy:  0.734, Loss:  0.464
# Epoch   1 Batch  470/538 - Train Accuracy:  0.727, Validation Accuracy:  0.726, Loss:  0.448
# Epoch   1 Batch  471/538 - Train Accuracy:  0.707, Validation Accuracy:  0.721, Loss:  0.453
# Epoch   1 Batch  472/538 - Train Accuracy:  0.724, Validation Accuracy:  0.730, Loss:  0.444
# Epoch   1 Batch  473/538 - Train Accuracy:  0.712, Validation Accuracy:  0.731, Loss:  0.465
# Epoch   1 Batch  474/538 - Train Accuracy:  0.698, Validation Accuracy:  0.713, Loss:  0.424
# Epoch   1 Batch  475/538 - Train Accuracy:  0.732, Validation Accuracy:  0.734, Loss:  0.442
# Epoch   1 Batch  476/538 - Train Accuracy:  0.734, Validation Accuracy:  0.718, Loss:  0.459
# Epoch   1 Batch  477/538 - Train Accuracy:  0.704, Validation Accuracy:  0.702, Loss:  0.460
# Epoch   1 Batch  478/538 - Train Accuracy:  0.729, Validation Accuracy:  0.696, Loss:  0.436
# Epoch   1 Batch  479/538 - Train Accuracy:  0.728, Validation Accuracy:  0.715, Loss:  0.430
# Epoch   1 Batch  480/538 - Train Accuracy:  0.717, Validation Accuracy:  0.713, Loss:  0.441
# Epoch   1 Batch  481/538 - Train Accuracy:  0.733, Validation Accuracy:  0.721, Loss:  0.435
# Epoch   1 Batch  482/538 - Train Accuracy:  0.707, Validation Accuracy:  0.694, Loss:  0.409
# Epoch   1 Batch  483/538 - Train Accuracy:  0.690, Validation Accuracy:  0.707, Loss:  0.469
# Epoch   1 Batch  484/538 - Train Accuracy:  0.729, Validation Accuracy:  0.715, Loss:  0.444
# Epoch   1 Batch  485/538 - Train Accuracy:  0.706, Validation Accuracy:  0.714, Loss:  0.437
# Epoch   1 Batch  486/538 - Train Accuracy:  0.721, Validation Accuracy:  0.711, Loss:  0.423
# Epoch   1 Batch  487/538 - Train Accuracy:  0.749, Validation Accuracy:  0.724, Loss:  0.423
# Epoch   1 Batch  488/538 - Train Accuracy:  0.719, Validation Accuracy:  0.719, Loss:  0.439
# Epoch   1 Batch  489/538 - Train Accuracy:  0.713, Validation Accuracy:  0.717, Loss:  0.462
# Epoch   1 Batch  490/538 - Train Accuracy:  0.735, Validation Accuracy:  0.722, Loss:  0.439
# Epoch   1 Batch  491/538 - Train Accuracy:  0.705, Validation Accuracy:  0.725, Loss:  0.463
# Epoch   1 Batch  492/538 - Train Accuracy:  0.719, Validation Accuracy:  0.735, Loss:  0.460
# Epoch   1 Batch  493/538 - Train Accuracy:  0.727, Validation Accuracy:  0.737, Loss:  0.425
# Epoch   1 Batch  494/538 - Train Accuracy:  0.723, Validation Accuracy:  0.729, Loss:  0.457
# Epoch   1 Batch  495/538 - Train Accuracy:  0.736, Validation Accuracy:  0.730, Loss:  0.452
# Epoch   1 Batch  496/538 - Train Accuracy:  0.710, Validation Accuracy:  0.738, Loss:  0.445
# Epoch   1 Batch  497/538 - Train Accuracy:  0.754, Validation Accuracy:  0.733, Loss:  0.435
# Epoch   1 Batch  498/538 - Train Accuracy:  0.721, Validation Accuracy:  0.739, Loss:  0.435
# Epoch   1 Batch  499/538 - Train Accuracy:  0.740, Validation Accuracy:  0.731, Loss:  0.428
# Epoch   1 Batch  500/538 - Train Accuracy:  0.749, Validation Accuracy:  0.728, Loss:  0.403
# Epoch   1 Batch  501/538 - Train Accuracy:  0.771, Validation Accuracy:  0.727, Loss:  0.438

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    words_to_ids_array = []
    for word in sentence.lower().split(" "):
        words_to_ids_array.append(vocab_to_int.get(word, "<UNK>")
    return words_to_ids_array


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))
# Out:
# Input
#   Word Ids:      [129, 166, 109, 28, 93, 42, 32]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [237, 129, 34, 34, 34, 181, 181, 181, 181, 181, 0, 0, 0, 0, 0, 0, 0, 0]
#   French Words: ['il', 'a', 'la', 'la', 'la', '.', '.', '.', '.', '.', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
