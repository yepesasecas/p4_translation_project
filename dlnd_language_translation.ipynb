# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of each sentence from `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    
    source_id_text = []
    target_id_text = []
#     print(source_vocab_to_int)
    
    source_phrases = source_text.split("\n")
    for phrase in source_phrases:
#         print(phrase)
        phrase_array = []
        for word in phrase.split(" "):
            if word != '':
                phrase_array.append(source_vocab_to_int[word])
        source_id_text.append(phrase_array)
#     print(source_id_text)        
    
    target_phrases = target_text.split("\n")
    for phrase in target_phrases:
#         print(phrase)
        phrase_array = []
        for word in phrase.split(" "):
            if word != '':
                phrase_array.append(target_vocab_to_int[word])
        phrase_array.append(target_vocab_to_int["<EOS>"])
        target_id_text.append(phrase_array)
     
    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) in [LooseVersion('1.0.0'), LooseVersion('1.0.1')], 'This project requires TensorFlow version 1.0  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
#
# Return the placeholders in the following the tuple (Input, Targets, Learing Rate, Keep Probability)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    # TODO: Implement Function
    inputs = tf.placeholder(tf.int32, shape=[None, None], name="input")
    targets = tf.placeholder(tf.int32, shape=[None, None], name="targets")
    learning_rate = tf.placeholder(tf.float32, name="learning_rate")
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    return inputs, targets, learning_rate, keep_prob

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoding Input
# Implement `process_decoding_input` using TensorFlow to remove the last word id from each batch in `target_data` and concat the GO ID to the beginning of each batch.

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for dencoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    print("target_data", target_data)
    print("target_vocab_to_int", target_vocab_to_int)
    print("batch_size", batch_size)
    
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)

    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
# Out:
# target_data Tensor("Placeholder:0", shape=(2, 3), dtype=int32)
# target_vocab_to_int {'<GO>': 3}
# batch_size 2
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer using [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn).

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """
    
     # TODO: Implement Function
    cell = tf.contrib.rnn.LSTMCell(rnn_size, state_is_tuple=True)
    cell = tf.contrib.rnn.DropoutWrapper(cell, output_keep_prob=keep_prob)
    cell = tf.contrib.rnn.MultiRNNCell([cell] * num_layers, state_is_tuple=True)
    _, enc_state = tf.nn.dynamic_rnn(cell = cell, inputs = rnn_inputs, dtype=tf.float32)

    return enc_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create training logits using [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).  Apply the `output_fn` to the [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) outputs.

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """

    train_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    train_pred, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, train_decoder_fn, dec_embed_input, sequence_length, scope=decoding_scope)    
    train_logits =  output_fn(train_pred)
    return train_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference logits using [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: The maximum allowed time steps to decode
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """
    # TODO: Implement Function
    inf_decoder = tf.contrib.seq2seq.simple_decoder_fn_inference(output_fn, encoder_state, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, dtype=tf.int32, name="inf_decoder_fn")
    dec_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob=keep_prob)
    inf_logits, _, _ =tf.contrib.seq2seq.dynamic_rnn_decoder(cell = dec_cell, decoder_fn = inf_decoder, scope = decoding_scope, name = "inf_logits")
    return inf_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# - Create RNN cell for decoding using `rnn_size` and `num_layers`.
# - Create the output fuction using [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) to transform it's input, logits, to class logits.
# - Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` function to get the training logits.
# - Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    
    # TODO: Implement Function
    start_of_sequence_id = target_vocab_to_int['<GO>']
    end_of_sequence_id = target_vocab_to_int['<EOS>']
        
    with tf.variable_scope("decoding") as decoding_scope:
        lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
        cell = tf.contrib.rnn.MultiRNNCell([lstm]*num_layers)
        output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, None, scope=decoding_scope)
        train_logits = decoding_layer_train(encoder_state, cell, dec_embed_input, sequence_length,decoding_scope, output_fn, keep_prob)
        decoding_scope.reuse_variables()
        inference_logits = decoding_layer_infer(encoder_state, cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, sequence_length, vocab_size, decoding_scope, output_fn, keep_prob)
    return train_logits, inference_logits

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)`.
# - Process target data using your `process_decoding_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)`.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    enc_input = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, enc_embedding_size)
    enc_layer = encoding_layer(enc_input, rnn_size, num_layers, keep_prob)
    
    dec_input = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    embed_target = tf.contrib.layers.embed_sequence(dec_input, target_vocab_size, dec_embedding_size)
    
    dec_embed = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size]))
    
    train_logits, inf_logits = decoding_layer(embed_target, dec_embed, enc_layer, target_vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)
    
    return train_logits, inf_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# target_data Tensor("Placeholder_1:0", shape=(64, 22), dtype=int32)
# target_vocab_to_int {'<GO>': 3, '<EOS>': 1}
# batch_size 64
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability

# %%
# Number of Epochs
epochs = 3
# Batch Size
batch_size = 256
# RNN Size
rnn_size = 128
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 256
decoding_embedding_size = 256
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.8

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)
# Out:
# target_data Tensor("targets:0", shape=(?, ?), dtype=int32)
# target_vocab_to_int {'france': 170, 'as-tu': 171, 'juin': 4, 'allez': 5, 'pousse': 6, 'favori': 172, 'va': 173, 'allions': 7, 'êtes-vous': 174, 'proches': 8, 'leurs': 175, 'verts': 9, 'lions': 136, 'pêche': 10, 'difficile': 176, 'grosse': 11, 'relaxant': 177, 'états-unis': 179, 'ressort': 180, '.': 181, 'animaux': 253, 'détestons': 12, 'visiter': 182, 'vers': 147, 'ne': 183, 'grandes': 184, 'citron': 13, 'lui': 185, 'petit': 186, 'magnifique': 14, 'blanc': 199, 'aimés': 15, 'pourrait': 16, 'anglais': 17, 'frais': 187, 'enneigé': 18, 'calme': 188, 'chaude': 19, 'neige': 20, 'notre': 21, 'est': 192, 'manguiers': 23, "l'automobile": 190, 'petits': 191, 'hiver': 24, 'aime': 25, 'août': 26, 'frisquet': 193, 'rouille': 28, 'grands': 123, 'été': 195, '-ce': 30, 'facile': 60, 'tranquille': 196, 'lac': 330, 'allée': 125, 'comme': 213, 'est-ce': 31, 'automne': 197, 'comment': 198, 'douce': 200, 'redouté': 264, 'des': 201, 'lapin': 32, 'pleut': 232, '-': 202, 'jaune': 203, 'automobile': 204, 'éléphants': 205, 'la': 34, 'pense': 266, 'cheval': 35, 'aiment-ils': 36, 'aux': 346, 'jersey': 207, "n'a": 37, 'oiseaux': 38, 'nouveau': 300, 'traduire': 22, 'mai': 209, 'pourraient': 210, 'enneigée': 211, 'petite': 40, 'elle': 178, 'faire': 33, 'déteste': 73, 'aimeraient': 214, 'habituellement': 42, "qu'elle": 128, 'maillot': 43, 'visite': 45, 'grande': 46, 'se': 216, 'votre': 47, 't': 48, 'français': 217, 'espagnol': 218, 'sec': 50, 'aimé.': 51, 'singes': 52, 'peu': 53, 'leur': 219, 'animal': 220, 'juillet': 221, 'a': 129, 'sont': 55, 'les': 222, 'terrain': 212, 'octobre': 130, 'légère': 334, 'rouillée': 224, 'février': 98, "j'aime": 225, 'qui': 56, 'congélation': 57, 'moteur': 226, 'pommes': 58, 'nos': 227, 'bleu': 228, 'pourquoi': 229, 'mes': 230, 'lion': 66, 'aimons': 231, 'new': 61, 'prévoient': 233, 'où': 234, 'préférés': 107, 'allons': 62, "n'aimez": 235, 'at': 64, 'vos': 238, 'california': 65, 'dernier': 169, 'pas': 236, 'le': 102, 'amusant': 309, 'il': 237, 'voulez': 67, 'mangues': 68, 'aimait': 69, 'noir': 239, 'nous': 240, 'mouillée': 70, 'novembre': 241, 'lapins': 72, 'prévois': 74, 'préférée': 150, 'trop': 146, 'chien': 242, 'vert': 243, 'requin': 75, 'souris': 244, 'au': 76, 'camion': 78, 'dernière': 245, 'détestez': 80, 'moindres': 81, 'avril': 82, 'oranges': 246, 'détend': 247, 'voudrait': 83, 'étaient': 84, 'pluies': 134, 'gros': 85, 'mon': 86, '<PAD>': 0, 'dans': 249, 'aiment': 250, 'fraises': 54, 'clémentes': 252, 'football': 87, '?': 71, "n'aime": 135, 'rouillé': 254, '<EOS>': 1, "l'automne": 255, 'détendre': 88, 'blanche': 256, 'et': 89, 'doux': 39, 'i': 90, 'belle': 257, "l'": 277, "l'ours": 91, 'cette': 258, 'ours': 63, '-ils': 92, 'brillante': 259, 'poires': 93, 'rendre': 152, 'allé': 94, 'pêches': 260, "l'école": 261, 'californie': 262, 'nouvelle': 263, 'humide': 95, '-il': 265, 'brillant': 267, 'redoutés': 268, 'avez': 96, 'glaciales': 97, 'volant': 269, 'fraise': 270, 'conduite': 271, 'ont': 272, 'mais': 100, 'temps': 273, 'es-tu': 103, 'voulait': 274, 'aimé': 108, 'monde': 275, 'mangue': 276, 'poire': 104, 'etats-unis': 278, 'paris': 105, 'chiens': 279, "l'épicerie": 106, 'pamplemousse': 280, 'portugais': 281, 'vont': 109, 'pamplemousses': 77, 'un': 110, 'raisins': 111, 'traduction': 282, 'préféré.': 112, 'voiture': 283, 'vais': 113, 'détestait': 114, "l'animal": 284, 'bénigne': 189, 'chevaux': 116, 'apprécié': 215, 'grand': 117, 'pomme': 286, 'vit': 119, 'pluvieux': 287, '<UNK>': 2, "n'êtes": 120, 'serpents': 79, "l'éléphant": 289, 'raisin': 291, 'sur': 292, 'je': 293, "n'aiment": 121, 'cépage': 295, 'entre': 296, 'souvent': 122, '<GO>': 3, 'envisagent': 124, 'redoutée': 126, 'agréable': 297, 'cet': 298, 'vu': 44, 'gelés': 299, 'prévoit': 127, 'veulent': 301, 'tour': 208, 'citrons': 302, 'plus': 303, 'petites': 304, 'aimée': 305, 'chaux': 131, 'quand': 306, 'durant': 115, 'occupé': 307, 'limes': 310, 'pendant': 132, "l'orange": 133, 'conduit': 311, 'à': 312, 'singe': 313, 'son': 49, 'neigeux': 99, 'intention': 314, 'en' ...
# batch_size 256

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/538 - Train Accuracy:  0.097, Validation Accuracy:  0.177, Loss:  5.878
# Epoch   0 Batch    1/538 - Train Accuracy:  0.097, Validation Accuracy:  0.177, Loss:  5.863
# Epoch   0 Batch    2/538 - Train Accuracy:  0.098, Validation Accuracy:  0.178, Loss:  5.840
# Epoch   0 Batch    3/538 - Train Accuracy:  0.111, Validation Accuracy:  0.195, Loss:  5.812
# Epoch   0 Batch    4/538 - Train Accuracy:  0.126, Validation Accuracy:  0.200, Loss:  5.756
# Epoch   0 Batch    5/538 - Train Accuracy:  0.173, Validation Accuracy:  0.206, Loss:  5.639
# Epoch   0 Batch    6/538 - Train Accuracy:  0.174, Validation Accuracy:  0.207, Loss:  5.448
# Epoch   0 Batch    7/538 - Train Accuracy:  0.143, Validation Accuracy:  0.214, Loss:  5.202
# Epoch   0 Batch    8/538 - Train Accuracy:  0.183, Validation Accuracy:  0.257, Loss:  4.896
# Epoch   0 Batch    9/538 - Train Accuracy:  0.212, Validation Accuracy:  0.291, Loss:  4.631
# Epoch   0 Batch   10/538 - Train Accuracy:  0.235, Validation Accuracy:  0.328, Loss:  4.511
# Epoch   0 Batch   11/538 - Train Accuracy:  0.269, Validation Accuracy:  0.345, Loss:  4.296
# Epoch   0 Batch   12/538 - Train Accuracy:  0.264, Validation Accuracy:  0.345, Loss:  4.186
# Epoch   0 Batch   13/538 - Train Accuracy:  0.316, Validation Accuracy:  0.346, Loss:  3.831
# Epoch   0 Batch   14/538 - Train Accuracy:  0.273, Validation Accuracy:  0.346, Loss:  3.902
# Epoch   0 Batch   15/538 - Train Accuracy:  0.319, Validation Accuracy:  0.346, Loss:  3.629
# Epoch   0 Batch   16/538 - Train Accuracy:  0.300, Validation Accuracy:  0.346, Loss:  3.577
# Epoch   0 Batch   17/538 - Train Accuracy:  0.284, Validation Accuracy:  0.346, Loss:  3.617
# Epoch   0 Batch   18/538 - Train Accuracy:  0.271, Validation Accuracy:  0.346, Loss:  3.599
# Epoch   0 Batch   19/538 - Train Accuracy:  0.270, Validation Accuracy:  0.346, Loss:  3.548
# Epoch   0 Batch   20/538 - Train Accuracy:  0.299, Validation Accuracy:  0.347, Loss:  3.359
# Epoch   0 Batch   21/538 - Train Accuracy:  0.225, Validation Accuracy:  0.347, Loss:  3.589
# Epoch   0 Batch   22/538 - Train Accuracy:  0.279, Validation Accuracy:  0.347, Loss:  3.377
# Epoch   0 Batch   23/538 - Train Accuracy:  0.284, Validation Accuracy:  0.347, Loss:  3.322
# Epoch   0 Batch   24/538 - Train Accuracy:  0.297, Validation Accuracy:  0.347, Loss:  3.240
# Epoch   0 Batch   25/538 - Train Accuracy:  0.282, Validation Accuracy:  0.347, Loss:  3.284
# Epoch   0 Batch   26/538 - Train Accuracy:  0.286, Validation Accuracy:  0.353, Loss:  3.259
# Epoch   0 Batch   27/538 - Train Accuracy:  0.291, Validation Accuracy:  0.356, Loss:  3.204
# Epoch   0 Batch   28/538 - Train Accuracy:  0.364, Validation Accuracy:  0.367, Loss:  2.913
# Epoch   0 Batch   29/538 - Train Accuracy:  0.329, Validation Accuracy:  0.369, Loss:  3.069
# Epoch   0 Batch   30/538 - Train Accuracy:  0.301, Validation Accuracy:  0.368, Loss:  3.185
# Epoch   0 Batch   31/538 - Train Accuracy:  0.333, Validation Accuracy:  0.369, Loss:  3.006
# Epoch   0 Batch   32/538 - Train Accuracy:  0.311, Validation Accuracy:  0.368, Loss:  3.094
# Epoch   0 Batch   33/538 - Train Accuracy:  0.331, Validation Accuracy:  0.369, Loss:  3.003
# Epoch   0 Batch   34/538 - Train Accuracy:  0.311, Validation Accuracy:  0.371, Loss:  3.100
# Epoch   0 Batch   35/538 - Train Accuracy:  0.296, Validation Accuracy:  0.371, Loss:  3.096
# Epoch   0 Batch   36/538 - Train Accuracy:  0.331, Validation Accuracy:  0.370, Loss:  2.961
# Epoch   0 Batch   37/538 - Train Accuracy:  0.308, Validation Accuracy:  0.373, Loss:  3.039
# Epoch   0 Batch   38/538 - Train Accuracy:  0.301, Validation Accuracy:  0.377, Loss:  3.075
# Epoch   0 Batch   39/538 - Train Accuracy:  0.315, Validation Accuracy:  0.378, Loss:  3.044
# Epoch   0 Batch   40/538 - Train Accuracy:  0.373, Validation Accuracy:  0.379, Loss:  2.774
# Epoch   0 Batch   41/538 - Train Accuracy:  0.313, Validation Accuracy:  0.379, Loss:  2.997
# Epoch   0 Batch   42/538 - Train Accuracy:  0.313, Validation Accuracy:  0.379, Loss:  2.971
# Epoch   0 Batch   43/538 - Train Accuracy:  0.322, Validation Accuracy:  0.378, Loss:  2.987
# Epoch   0 Batch   44/538 - Train Accuracy:  0.305, Validation Accuracy:  0.379, Loss:  2.998
# Epoch   0 Batch   45/538 - Train Accuracy:  0.352, Validation Accuracy:  0.380, Loss:  2.844
# Epoch   0 Batch   46/538 - Train Accuracy:  0.319, Validation Accuracy:  0.380, Loss:  2.943
# Epoch   0 Batch   47/538 - Train Accuracy:  0.355, Validation Accuracy:  0.381, Loss:  2.817
# Epoch   0 Batch   48/538 - Train Accuracy:  0.368, Validation Accuracy:  0.382, Loss:  2.781
# Epoch   0 Batch   49/538 - Train Accuracy:  0.302, Validation Accuracy:  0.381, Loss:  2.975
# Epoch   0 Batch   50/538 - Train Accuracy:  0.322, Validation Accuracy:  0.382, Loss:  2.889
# Epoch   0 Batch   51/538 - Train Accuracy:  0.267, Validation Accuracy:  0.384, Loss:  3.100
# Epoch   0 Batch   52/538 - Train Accuracy:  0.338, Validation Accuracy:  0.385, Loss:  2.882
# Epoch   0 Batch   53/538 - Train Accuracy:  0.376, Validation Accuracy:  0.385, Loss:  2.658
# Epoch   0 Batch   54/538 - Train Accuracy:  0.330, Validation Accuracy:  0.385, Loss:  2.853
# Epoch   0 Batch   55/538 - Train Accuracy:  0.316, Validation Accuracy:  0.387, Loss:  2.878
# Epoch   0 Batch   56/538 - Train Accuracy:  0.353, Validation Accuracy:  0.390, Loss:  2.756
# Epoch   0 Batch   57/538 - Train Accuracy:  0.315, Validation Accuracy:  0.391, Loss:  2.896
# Epoch   0 Batch   58/538 - Train Accuracy:  0.311, Validation Accuracy:  0.391, Loss:  2.889
# Epoch   0 Batch   59/538 - Train Accuracy:  0.317, Validation Accuracy:  0.387, Loss:  2.865
# Epoch   0 Batch   60/538 - Train Accuracy:  0.321, Validation Accuracy:  0.387, Loss:  2.821
# Epoch   0 Batch   61/538 - Train Accuracy:  0.329, Validation Accuracy:  0.391, Loss:  2.801
# Epoch   0 Batch   62/538 - Train Accuracy:  0.339, Validation Accuracy:  0.387, Loss:  2.746
# Epoch   0 Batch   63/538 - Train Accuracy:  0.360, Validation Accuracy:  0.387, Loss:  2.665
# Epoch   0 Batch   64/538 - Train Accuracy:  0.362, Validation Accuracy:  0.393, Loss:  2.678
# Epoch   0 Batch   65/538 - Train Accuracy:  0.315, Validation Accuracy:  0.388, Loss:  2.835
# Epoch   0 Batch   66/538 - Train Accuracy:  0.355, Validation Accuracy:  0.393, Loss:  2.669
# Epoch   0 Batch   67/538 - Train Accuracy:  0.336, Validation Accuracy:  0.393, Loss:  2.735
# Epoch   0 Batch   68/538 - Train Accuracy:  0.360, Validation Accuracy:  0.399, Loss:  2.607
# Epoch   0 Batch   69/538 - Train Accuracy:  0.330, Validation Accuracy:  0.395, Loss:  2.753
# Epoch   0 Batch   70/538 - Train Accuracy:  0.358, Validation Accuracy:  0.396, Loss:  2.634
# Epoch   0 Batch   71/538 - Train Accuracy:  0.334, Validation Accuracy:  0.396, Loss:  2.722
# Epoch   0 Batch   72/538 - Train Accuracy:  0.361, Validation Accuracy:  0.396, Loss:  2.600
# Epoch   0 Batch   73/538 - Train Accuracy:  0.327, Validation Accuracy:  0.397, Loss:  2.729
# Epoch   0 Batch   74/538 - Train Accuracy:  0.367, Validation Accuracy:  0.399, Loss:  2.600
# Epoch   0 Batch   75/538 - Train Accuracy:  0.370, Validation Accuracy:  0.400, Loss:  2.575
# Epoch   0 Batch   76/538 - Train Accuracy:  0.327, Validation Accuracy:  0.400, Loss:  2.734
# Epoch   0 Batch   77/538 - Train Accuracy:  0.332, Validation Accuracy:  0.404, Loss:  2.692
# Epoch   0 Batch   78/538 - Train Accuracy:  0.368, Validation Accuracy:  0.403, Loss:  2.592
# Epoch   0 Batch   79/538 - Train Accuracy:  0.360, Validation Accuracy:  0.401, Loss:  2.544
# Epoch   0 Batch   80/538 - Train Accuracy:  0.331, Validation Accuracy:  0.405, Loss:  2.692
# Epoch   0 Batch   81/538 - Train Accuracy:  0.327, Validation Accuracy:  0.402, Loss:  2.689
# Epoch   0 Batch   82/538 - Train Accuracy:  0.340, Validation Accuracy:  0.401, Loss:  2.612
# Epoch   0 Batch   83/538 - Train Accuracy:  0.333, Validation Accuracy:  0.404, Loss:  2.657
# Epoch   0 Batch   84/538 - Train Accuracy:  0.362, Validation Accuracy:  0.404, Loss:  2.544
# Epoch   0 Batch   85/538 - Train Accuracy:  0.388, Validation Accuracy:  0.402, Loss:  2.429
# Epoch   0 Batch   86/538 - Train Accuracy:  0.338, Validation Accuracy:  0.404, Loss:  2.644
# Epoch   0 Batch   87/538 - Train Accuracy:  0.336, Validation Accuracy:  0.400, Loss:  2.587
# Epoch   0 Batch   88/538 - Train Accuracy:  0.342, Validation Accuracy:  0.397, Loss:  2.594
# Epoch   0 Batch   89/538 - Train Accuracy:  0.344, Validation Accuracy:  0.398, Loss:  2.582
# Epoch   0 Batch   90/538 - Train Accuracy:  0.364, Validation Accuracy:  0.400, Loss:  2.489
# Epoch   0 Batch   91/538 - Train Accuracy:  0.319, Validation Accuracy:  0.398, Loss:  2.619
# Epoch   0 Batch   92/538 - Train Accuracy:  0.340, Validation Accuracy:  0.398, Loss:  2.557
# Epoch   0 Batch   93/538 - Train Accuracy:  0.323, Validation Accuracy:  0.402, Loss:  2.586
# Epoch   0 Batch   94/538 - Train Accuracy:  0.323, Validation Accuracy:  0.399, Loss:  2.634
# Epoch   0 Batch   95/538 - Train Accuracy:  0.385, Validation Accuracy:  0.398, Loss:  2.356
# Epoch   0 Batch   96/538 - Train Accuracy:  0.369, Validation Accuracy:  0.400, Loss:  2.403
# Epoch   0 Batch   97/538 - Train Accuracy:  0.323, Validation Accuracy:  0.400, Loss:  2.551
# Epoch   0 Batch   98/538 - Train Accuracy:  0.371, Validation Accuracy:  0.399, Loss:  2.371
# Epoch   0 Batch   99/538 - Train Accuracy:  0.336, Validation Accuracy:  0.403, Loss:  2.546
# Epoch   0 Batch  100/538 - Train Accuracy:  0.347, Validation Accuracy:  0.410, Loss:  2.498
# Epoch   0 Batch  101/538 - Train Accuracy:  0.348, Validation Accuracy:  0.407, Loss:  2.486
# Epoch   0 Batch  102/538 - Train Accuracy:  0.344, Validation Accuracy:  0.408, Loss:  2.540
# Epoch   0 Batch  103/538 - Train Accuracy:  0.365, Validation Accuracy:  0.413, Loss:  2.440
# Epoch   0 Batch  104/538 - Train Accuracy:  0.366, Validation Accuracy:  0.407, Loss:  2.424
# Epoch   0 Batch  105/538 - Train Accuracy:  0.371, Validation Accuracy:  0.408, Loss:  2.375
# Epoch   0 Batch  106/538 - Train Accuracy:  0.340, Validation Accuracy:  0.410, Loss:  2.484
# Epoch   0 Batch  107/538 - Train Accuracy:  0.334, Validation Accuracy:  0.409, Loss:  2.512
# Epoch   0 Batch  108/538 - Train Accuracy:  0.359, Validation Accuracy:  0.408, Loss:  2.453
# Epoch   0 Batch  109/538 - Train Accuracy:  0.346, Validation Accuracy:  0.409, Loss:  2.470
# Epoch   0 Batch  110/538 - Train Accuracy:  0.344, Validation Accuracy:  0.412, Loss:  2.484
# Epoch   0 Batch  111/538 - Train Accuracy:  0.374, Validation Accuracy:  0.409, Loss:  2.361
# Epoch   0 Batch  112/538 - Train Accuracy:  0.336, Validation Accuracy:  0.410, Loss:  2.464
# Epoch   0 Batch  113/538 - Train Accuracy:  0.341, Validation Accuracy:  0.412, Loss:  2.468
# Epoch   0 Batch  114/538 - Train Accuracy:  0.385, Validation Accuracy:  0.412, Loss:  2.313
# Epoch   0 Batch  115/538 - Train Accuracy:  0.344, Validation Accuracy:  0.411, Loss:  2.433
# Epoch   0 Batch  116/538 - Train Accuracy:  0.381, Validation Accuracy:  0.412, Loss:  2.346
# Epoch   0 Batch  117/538 - Train Accuracy:  0.381, Validation Accuracy:  0.412, Loss:  2.318
# Epoch   0 Batch  118/538 - Train Accuracy:  0.380, Validation Accuracy:  0.413, Loss:  2.316
# Epoch   0 Batch  119/538 - Train Accuracy:  0.382, Validation Accuracy:  0.414, Loss:  2.287
# Epoch   0 Batch  120/538 - Train Accuracy:  0.340, Validation Accuracy:  0.414, Loss:  2.399
# Epoch   0 Batch  121/538 - Train Accuracy:  0.383, Validation Accuracy:  0.414, Loss:  2.270
# Epoch   0 Batch  122/538 - Train Accuracy:  0.364, Validation Accuracy:  0.414, Loss:  2.301
# Epoch   0 Batch  123/538 - Train Accuracy:  0.393, Validation Accuracy:  0.414, Loss:  2.252
# Epoch   0 Batch  124/538 - Train Accuracy:  0.399, Validation Accuracy:  0.413, Loss:  2.209
# Epoch   0 Batch  125/538 - Train Accuracy:  0.369, Validation Accuracy:  0.414, Loss:  2.296
# Epoch   0 Batch  126/538 - Train Accuracy:  0.401, Validation Accuracy:  0.414, Loss:  2.202
# Epoch   0 Batch  127/538 - Train Accuracy:  0.342, Validation Accuracy:  0.415, Loss:  2.382
# Epoch   0 Batch  128/538 - Train Accuracy:  0.378, Validation Accuracy:  0.415, Loss:  2.237
# Epoch   0 Batch  129/538 - Train Accuracy:  0.377, Validation Accuracy:  0.415, Loss:  2.256
# Epoch   0 Batch  130/538 - Train Accuracy:  0.371, Validation Accuracy:  0.415, Loss:  2.277
# Epoch   0 Batch  131/538 - Train Accuracy:  0.346, Validation Accuracy:  0.414, Loss:  2.365
# Epoch   0 Batch  132/538 - Train Accuracy:  0.381, Validation Accuracy:  0.413, Loss:  2.211
# Epoch   0 Batch  133/538 - Train Accuracy:  0.392, Validation Accuracy:  0.413, Loss:  2.167
# Epoch   0 Batch  134/538 - Train Accuracy:  0.333, Validation Accuracy:  0.415, Loss:  2.401
# Epoch   0 Batch  135/538 - Train Accuracy:  0.369, Validation Accuracy:  0.415, Loss:  2.239
# Epoch   0 Batch  136/538 - Train Accuracy:  0.365, Validation Accuracy:  0.414, Loss:  2.254
# Epoch   0 Batch  137/538 - Train Accuracy:  0.380, Validation Accuracy:  0.416, Loss:  2.219
# Epoch   0 Batch  138/538 - Train Accuracy:  0.372, Validation Accuracy:  0.414, Loss:  2.248
# Epoch   0 Batch  139/538 - Train Accuracy:  0.341, Validation Accuracy:  0.411, Loss:  2.380
# Epoch   0 Batch  140/538 - Train Accuracy:  0.349, Validation Accuracy:  0.417, Loss:  2.333
# Epoch   0 Batch  141/538 - Train Accuracy:  0.350, Validation Accuracy:  0.412, Loss:  2.335
# Epoch   0 Batch  142/538 - Train Accuracy:  0.391, Validation Accuracy:  0.414, Loss:  2.153
# Epoch   0 Batch  143/538 - Train Accuracy:  0.334, Validation Accuracy:  0.416, Loss:  2.329
# Epoch   0 Batch  144/538 - Train Accuracy:  0.354, Validation Accuracy:  0.413, Loss:  2.288
# Epoch   0 Batch  145/538 - Train Accuracy:  0.382, Validation Accuracy:  0.415, Loss:  2.202
# Epoch   0 Batch  146/538 - Train Accuracy:  0.396, Validation Accuracy:  0.415, Loss:  2.115
# Epoch   0 Batch  147/538 - Train Accuracy:  0.390, Validation Accuracy:  0.415, Loss:  2.154
# Epoch   0 Batch  148/538 - Train Accuracy:  0.340, Validation Accuracy:  0.416, Loss:  2.321
# Epoch   0 Batch  149/538 - Train Accuracy:  0.352, Validation Accuracy:  0.415, Loss:  2.236
# Epoch   0 Batch  150/538 - Train Accuracy:  0.354, Validation Accuracy:  0.414, Loss:  2.238
# Epoch   0 Batch  151/538 - Train Accuracy:  0.376, Validation Accuracy:  0.414, Loss:  2.142
# Epoch   0 Batch  152/538 - Train Accuracy:  0.378, Validation Accuracy:  0.414, Loss:  2.149
# Epoch   0 Batch  153/538 - Train Accuracy:  0.353, Validation Accuracy:  0.414, Loss:  2.229
# Epoch   0 Batch  154/538 - Train Accuracy:  0.369, Validation Accuracy:  0.414, Loss:  2.161
# Epoch   0 Batch  155/538 - Train Accuracy:  0.388, Validation Accuracy:  0.414, Loss:  2.142
# Epoch   0 Batch  156/538 - Train Accuracy:  0.349, Validation Accuracy:  0.415, Loss:  2.239
# Epoch   0 Batch  157/538 - Train Accuracy:  0.367, Validation Accuracy:  0.415, Loss:  2.156
# Epoch   0 Batch  158/538 - Train Accuracy:  0.348, Validation Accuracy:  0.416, Loss:  2.265
# Epoch   0 Batch  159/538 - Train Accuracy:  0.348, Validation Accuracy:  0.417, Loss:  2.243
# Epoch   0 Batch  160/538 - Train Accuracy:  0.373, Validation Accuracy:  0.417, Loss:  2.123
# Epoch   0 Batch  161/538 - Train Accuracy:  0.358, Validation Accuracy:  0.416, Loss:  2.172
# Epoch   0 Batch  162/538 - Train Accuracy:  0.391, Validation Accuracy:  0.416, Loss:  2.052
# Epoch   0 Batch  163/538 - Train Accuracy:  0.381, Validation Accuracy:  0.416, Loss:  2.133
# Epoch   0 Batch  164/538 - Train Accuracy:  0.353, Validation Accuracy:  0.415, Loss:  2.216
# Epoch   0 Batch  165/538 - Train Accuracy:  0.391, Validation Accuracy:  0.418, Loss:  2.019
# Epoch   0 Batch  166/538 - Train Accuracy:  0.356, Validation Accuracy:  0.411, Loss:  2.184
# Epoch   0 Batch  167/538 - Train Accuracy:  0.388, Validation Accuracy:  0.413, Loss:  2.038
# Epoch   0 Batch  168/538 - Train Accuracy:  0.348, Validation Accuracy:  0.412, Loss:  2.160
# Epoch   0 Batch  169/538 - Train Accuracy:  0.354, Validation Accuracy:  0.412, Loss:  2.129
# Epoch   0 Batch  170/538 - Train Accuracy:  0.374, Validation Accuracy:  0.414, Loss:  2.100
# Epoch   0 Batch  171/538 - Train Accuracy:  0.340, Validation Accuracy:  0.414, Loss:  2.174
# Epoch   0 Batch  172/538 - Train Accuracy:  0.365, Validation Accuracy:  0.412, Loss:  2.085
# Epoch   0 Batch  173/538 - Train Accuracy:  0.375, Validation Accuracy:  0.414, Loss:  2.060
# Epoch   0 Batch  174/538 - Train Accuracy:  0.327, Validation Accuracy:  0.409, Loss:  2.196
# Epoch   0 Batch  175/538 - Train Accuracy:  0.322, Validation Accuracy:  0.411, Loss:  2.241
# Epoch   0 Batch  176/538 - Train Accuracy:  0.343, Validation Accuracy:  0.411, Loss:  2.165
# Epoch   0 Batch  177/538 - Train Accuracy:  0.371, Validation Accuracy:  0.409, Loss:  2.084
# Epoch   0 Batch  178/538 - Train Accuracy:  0.393, Validation Accuracy:  0.412, Loss:  1.975
# Epoch   0 Batch  179/538 - Train Accuracy:  0.350, Validation Accuracy:  0.410, Loss:  2.115
# Epoch   0 Batch  180/538 - Train Accuracy:  0.376, Validation Accuracy:  0.405, Loss:  2.024
# Epoch   0 Batch  181/538 - Train Accuracy:  0.333, Validation Accuracy:  0.407, Loss:  2.134
# Epoch   0 Batch  182/538 - Train Accuracy:  0.323, Validation Accuracy:  0.405, Loss:  2.131
# Epoch   0 Batch  183/538 - Train Accuracy:  0.376, Validation Accuracy:  0.405, Loss:  1.997
# Epoch   0 Batch  184/538 - Train Accuracy:  0.367, Validation Accuracy:  0.405, Loss:  2.006
# Epoch   0 Batch  185/538 - Train Accuracy:  0.348, Validation Accuracy:  0.403, Loss:  2.054
# Epoch   0 Batch  186/538 - Train Accuracy:  0.355, Validation Accuracy:  0.402, Loss:  2.036
# Epoch   0 Batch  187/538 - Train Accuracy:  0.393, Validation Accuracy:  0.403, Loss:  1.937
# Epoch   0 Batch  188/538 - Train Accuracy:  0.321, Validation Accuracy:  0.403, Loss:  2.093
# Epoch   0 Batch  189/538 - Train Accuracy:  0.331, Validation Accuracy:  0.400, Loss:  2.053
# Epoch   0 Batch  190/538 - Train Accuracy:  0.376, Validation Accuracy:  0.404, Loss:  2.019
# Epoch   0 Batch  191/538 - Train Accuracy:  0.370, Validation Accuracy:  0.400, Loss:  1.960
# Epoch   0 Batch  192/538 - Train Accuracy:  0.354, Validation Accuracy:  0.397, Loss:  1.967
# Epoch   0 Batch  193/538 - Train Accuracy:  0.376, Validation Accuracy:  0.400, Loss:  1.934
# Epoch   0 Batch  194/538 - Train Accuracy:  0.319, Validation Accuracy:  0.399, Loss:  2.068
# Epoch   0 Batch  195/538 - Train Accuracy:  0.376, Validation Accuracy:  0.395, Loss:  1.914
# Epoch   0 Batch  196/538 - Train Accuracy:  0.357, Validation Accuracy:  0.401, Loss:  1.971
# Epoch   0 Batch  197/538 - Train Accuracy:  0.368, Validation Accuracy:  0.398, Loss:  1.910
# Epoch   0 Batch  198/538 - Train Accuracy:  0.368, Validation Accuracy:  0.394, Loss:  1.889
# Epoch   0 Batch  199/538 - Train Accuracy:  0.321, Validation Accuracy:  0.394, Loss:  2.052
# Epoch   0 Batch  200/538 - Train Accuracy:  0.325, Validation Accuracy:  0.394, Loss:  2.005
# Epoch   0 Batch  201/538 - Train Accuracy:  0.368, Validation Accuracy:  0.392, Loss:  1.878
# Epoch   0 Batch  202/538 - Train Accuracy:  0.311, Validation Accuracy:  0.395, Loss:  2.044
# Epoch   0 Batch  203/538 - Train Accuracy:  0.330, Validation Accuracy:  0.396, Loss:  2.004
# Epoch   0 Batch  204/538 - Train Accuracy:  0.323, Validation Accuracy:  0.394, Loss:  1.982
# Epoch   0 Batch  205/538 - Train Accuracy:  0.364, Validation Accuracy:  0.393, Loss:  1.877
# Epoch   0 Batch  206/538 - Train Accuracy:  0.313, Validation Accuracy:  0.389, Loss:  1.976
# Epoch   0 Batch  207/538 - Train Accuracy:  0.359, Validation Accuracy:  0.388, Loss:  1.881
# Epoch   0 Batch  208/538 - Train Accuracy:  0.321, Validation Accuracy:  0.388, Loss:  1.957
# Epoch   0 Batch  209/538 - Train Accuracy:  0.313, Validation Accuracy:  0.390, Loss:  1.977
# Epoch   0 Batch  210/538 - Train Accuracy:  0.348, Validation Accuracy:  0.388, Loss:  1.860
# Epoch   0 Batch  211/538 - Train Accuracy:  0.318, Validation Accuracy:  0.387, Loss:  1.962
# Epoch   0 Batch  212/538 - Train Accuracy:  0.344, Validation Accuracy:  0.387, Loss:  1.865
# Epoch   0 Batch  213/538 - Train Accuracy:  0.336, Validation Accuracy:  0.387, Loss:  1.888
# Epoch   0 Batch  214/538 - Train Accuracy:  0.319, Validation Accuracy:  0.387, Loss:  1.917
# Epoch   0 Batch  215/538 - Train Accuracy:  0.313, Validation Accuracy:  0.387, Loss:  1.931
# Epoch   0 Batch  216/538 - Train Accuracy:  0.299, Validation Accuracy:  0.388, Loss:  1.946
# Epoch   0 Batch  217/538 - Train Accuracy:  0.350, Validation Accuracy:  0.388, Loss:  1.837
# Epoch   0 Batch  218/538 - Train Accuracy:  0.303, Validation Accuracy:  0.387, Loss:  1.895
# Epoch   0 Batch  219/538 - Train Accuracy:  0.316, Validation Accuracy:  0.388, Loss:  1.922
# Epoch   0 Batch  220/538 - Train Accuracy:  0.353, Validation Accuracy:  0.389, Loss:  1.807
# Epoch   0 Batch  221/538 - Train Accuracy:  0.343, Validation Accuracy:  0.388, Loss:  1.835
# Epoch   0 Batch  222/538 - Train Accuracy:  0.354, Validation Accuracy:  0.388, Loss:  1.764
# Epoch   0 Batch  223/538 - Train Accuracy:  0.323, Validation Accuracy:  0.388, Loss:  1.902
# Epoch   0 Batch  224/538 - Train Accuracy:  0.310, Validation Accuracy:  0.387, Loss:  1.920
# Epoch   0 Batch  225/538 - Train Accuracy:  0.355, Validation Accuracy:  0.388, Loss:  1.760
# Epoch   0 Batch  226/538 - Train Accuracy:  0.339, Validation Accuracy:  0.389, Loss:  1.768
# Epoch   0 Batch  227/538 - Train Accuracy:  0.383, Validation Accuracy:  0.387, Loss:  1.684
# Epoch   0 Batch  228/538 - Train Accuracy:  0.341, Validation Accuracy:  0.386, Loss:  1.766
# Epoch   0 Batch  229/538 - Train Accuracy:  0.350, Validation Accuracy:  0.387, Loss:  1.756
# Epoch   0 Batch  230/538 - Train Accuracy:  0.316, Validation Accuracy:  0.387, Loss:  1.825
# Epoch   0 Batch  231/538 - Train Accuracy:  0.320, Validation Accuracy:  0.385, Loss:  1.796
# Epoch   0 Batch  232/538 - Train Accuracy:  0.303, Validation Accuracy:  0.387, Loss:  1.831
# Epoch   0 Batch  233/538 - Train Accuracy:  0.364, Validation Accuracy:  0.387, Loss:  1.745
# Epoch   0 Batch  234/538 - Train Accuracy:  0.314, Validation Accuracy:  0.386, Loss:  1.811
# Epoch   0 Batch  235/538 - Train Accuracy:  0.342, Validation Accuracy:  0.386, Loss:  1.735
# Epoch   0 Batch  236/538 - Train Accuracy:  0.312, Validation Accuracy:  0.386, Loss:  1.791
# Epoch   0 Batch  237/538 - Train Accuracy:  0.331, Validation Accuracy:  0.386, Loss:  1.718
# Epoch   0 Batch  238/538 - Train Accuracy:  0.360, Validation Accuracy:  0.386, Loss:  1.668
# Epoch   0 Batch  239/538 - Train Accuracy:  0.327, Validation Accuracy:  0.386, Loss:  1.785
# Epoch   0 Batch  240/538 - Train Accuracy:  0.337, Validation Accuracy:  0.386, Loss:  1.758
# Epoch   0 Batch  241/538 - Train Accuracy:  0.317, Validation Accuracy:  0.388, Loss:  1.763
# Epoch   0 Batch  242/538 - Train Accuracy:  0.318, Validation Accuracy:  0.388, Loss:  1.750
# Epoch   0 Batch  243/538 - Train Accuracy:  0.291, Validation Accuracy:  0.388, Loss:  1.816
# Epoch   0 Batch  244/538 - Train Accuracy:  0.340, Validation Accuracy:  0.389, Loss:  1.682
# Epoch   0 Batch  245/538 - Train Accuracy:  0.332, Validation Accuracy:  0.389, Loss:  1.726
# Epoch   0 Batch  246/538 - Train Accuracy:  0.354, Validation Accuracy:  0.388, Loss:  1.631
# Epoch   0 Batch  247/538 - Train Accuracy:  0.310, Validation Accuracy:  0.388, Loss:  1.749
# Epoch   0 Batch  248/538 - Train Accuracy:  0.315, Validation Accuracy:  0.389, Loss:  1.713
# Epoch   0 Batch  249/538 - Train Accuracy:  0.340, Validation Accuracy:  0.387, Loss:  1.625
# Epoch   0 Batch  250/538 - Train Accuracy:  0.315, Validation Accuracy:  0.386, Loss:  1.698
# Epoch   0 Batch  251/538 - Train Accuracy:  0.313, Validation Accuracy:  0.387, Loss:  1.696
# Epoch   0 Batch  252/538 - Train Accuracy:  0.349, Validation Accuracy:  0.387, Loss:  1.585
# Epoch   0 Batch  253/538 - Train Accuracy:  0.348, Validation Accuracy:  0.386, Loss:  1.602
# Epoch   0 Batch  254/538 - Train Accuracy:  0.331, Validation Accuracy:  0.387, Loss:  1.651
# Epoch   0 Batch  255/538 - Train Accuracy:  0.326, Validation Accuracy:  0.387, Loss:  1.686
# Epoch   0 Batch  256/538 - Train Accuracy:  0.320, Validation Accuracy:  0.386, Loss:  1.670
# Epoch   0 Batch  257/538 - Train Accuracy:  0.361, Validation Accuracy:  0.386, Loss:  1.594
# Epoch   0 Batch  258/538 - Train Accuracy:  0.357, Validation Accuracy:  0.387, Loss:  1.566
# Epoch   0 Batch  259/538 - Train Accuracy:  0.350, Validation Accuracy:  0.386, Loss:  1.596
# Epoch   0 Batch  260/538 - Train Accuracy:  0.351, Validation Accuracy:  0.386, Loss:  1.599
# Epoch   0 Batch  261/538 - Train Accuracy:  0.312, Validation Accuracy:  0.386, Loss:  1.671
# Epoch   0 Batch  262/538 - Train Accuracy:  0.306, Validation Accuracy:  0.386, Loss:  1.690
# Epoch   0 Batch  263/538 - Train Accuracy:  0.336, Validation Accuracy:  0.385, Loss:  1.629
# Epoch   0 Batch  264/538 - Train Accuracy:  0.312, Validation Accuracy:  0.386, Loss:  1.627
# Epoch   0 Batch  265/538 - Train Accuracy:  0.308, Validation Accuracy:  0.387, Loss:  1.633
# Epoch   0 Batch  266/538 - Train Accuracy:  0.344, Validation Accuracy:  0.385, Loss:  1.562
# Epoch   0 Batch  267/538 - Train Accuracy:  0.320, Validation Accuracy:  0.385, Loss:  1.607
# Epoch   0 Batch  268/538 - Train Accuracy:  0.342, Validation Accuracy:  0.387, Loss:  1.535
# Epoch   0 Batch  269/538 - Train Accuracy:  0.330, Validation Accuracy:  0.387, Loss:  1.565
# Epoch   0 Batch  270/538 - Train Accuracy:  0.306, Validation Accuracy:  0.387, Loss:  1.605
# Epoch   0 Batch  271/538 - Train Accuracy:  0.309, Validation Accuracy:  0.387, Loss:  1.603
# Epoch   0 Batch  272/538 - Train Accuracy:  0.299, Validation Accuracy:  0.387, Loss:  1.656
# Epoch   0 Batch  273/538 - Train Accuracy:  0.327, Validation Accuracy:  0.386, Loss:  1.566
# Epoch   0 Batch  274/538 - Train Accuracy:  0.298, Validation Accuracy:  0.386, Loss:  1.623
# Epoch   0 Batch  275/538 - Train Accuracy:  0.320, Validation Accuracy:  0.386, Loss:  1.583
# Epoch   0 Batch  276/538 - Train Accuracy:  0.319, Validation Accuracy:  0.386, Loss:  1.570
# Epoch   0 Batch  277/538 - Train Accuracy:  0.323, Validation Accuracy:  0.386, Loss:  1.534
# Epoch   0 Batch  278/538 - Train Accuracy:  0.317, Validation Accuracy:  0.385, Loss:  1.516
# Epoch   0 Batch  279/538 - Train Accuracy:  0.324, Validation Accuracy:  0.385, Loss:  1.519
# Epoch   0 Batch  280/538 - Train Accuracy:  0.354, Validation Accuracy:  0.386, Loss:  1.460
# Epoch   0 Batch  281/538 - Train Accuracy:  0.325, Validation Accuracy:  0.388, Loss:  1.528
# Epoch   0 Batch  282/538 - Train Accuracy:  0.340, Validation Accuracy:  0.389, Loss:  1.479
# Epoch   0 Batch  283/538 - Train Accuracy:  0.334, Validation Accuracy:  0.390, Loss:  1.473
# Epoch   0 Batch  284/538 - Train Accuracy:  0.327, Validation Accuracy:  0.390, Loss:  1.497
# Epoch   0 Batch  285/538 - Train Accuracy:  0.349, Validation Accuracy:  0.389, Loss:  1.436
# Epoch   0 Batch  286/538 - Train Accuracy:  0.336, Validation Accuracy:  0.390, Loss:  1.503
# Epoch   0 Batch  287/538 - Train Accuracy:  0.349, Validation Accuracy:  0.390, Loss:  1.442
# Epoch   0 Batch  288/538 - Train Accuracy:  0.307, Validation Accuracy:  0.391, Loss:  1.527
# Epoch   0 Batch  289/538 - Train Accuracy:  0.352, Validation Accuracy:  0.390, Loss:  1.416
# Epoch   0 Batch  290/538 - Train Accuracy:  0.324, Validation Accuracy:  0.391, Loss:  1.499
# Epoch   0 Batch  291/538 - Train Accuracy:  0.342, Validation Accuracy:  0.394, Loss:  1.455
# Epoch   0 Batch  292/538 - Train Accuracy:  0.358, Validation Accuracy:  0.395, Loss:  1.389
# Epoch   0 Batch  293/538 - Train Accuracy:  0.360, Validation Accuracy:  0.392, Loss:  1.412
# Epoch   0 Batch  294/538 - Train Accuracy:  0.294, Validation Accuracy:  0.393, Loss:  1.533
# Epoch   0 Batch  295/538 - Train Accuracy:  0.383, Validation Accuracy:  0.395, Loss:  1.355
# Epoch   0 Batch  296/538 - Train Accuracy:  0.350, Validation Accuracy:  0.393, Loss:  1.403
# Epoch   0 Batch  297/538 - Train Accuracy:  0.309, Validation Accuracy:  0.392, Loss:  1.512
# Epoch   0 Batch  298/538 - Train Accuracy:  0.355, Validation Accuracy:  0.394, Loss:  1.430
# Epoch   0 Batch  299/538 - Train Accuracy:  0.358, Validation Accuracy:  0.393, Loss:  1.399
# Epoch   0 Batch  300/538 - Train Accuracy:  0.364, Validation Accuracy:  0.392, Loss:  1.356
# Epoch   0 Batch  301/538 - Train Accuracy:  0.351, Validation Accuracy:  0.393, Loss:  1.422
# Epoch   0 Batch  302/538 - Train Accuracy:  0.372, Validation Accuracy:  0.394, Loss:  1.341
# Epoch   0 Batch  303/538 - Train Accuracy:  0.395, Validation Accuracy:  0.395, Loss:  1.315
# Epoch   0 Batch  304/538 - Train Accuracy:  0.330, Validation Accuracy:  0.393, Loss:  1.436
# Epoch   0 Batch  305/538 - Train Accuracy:  0.345, Validation Accuracy:  0.392, Loss:  1.360
# Epoch   0 Batch  306/538 - Train Accuracy:  0.359, Validation Accuracy:  0.394, Loss:  1.363
# Epoch   0 Batch  307/538 - Train Accuracy:  0.341, Validation Accuracy:  0.395, Loss:  1.383
# Epoch   0 Batch  308/538 - Train Accuracy:  0.344, Validation Accuracy:  0.395, Loss:  1.370
# Epoch   0 Batch  309/538 - Train Accuracy:  0.321, Validation Accuracy:  0.395, Loss:  1.424
# Epoch   0 Batch  310/538 - Train Accuracy:  0.320, Validation Accuracy:  0.399, Loss:  1.410
# Epoch   0 Batch  311/538 - Train Accuracy:  0.369, Validation Accuracy:  0.400, Loss:  1.321
# Epoch   0 Batch  312/538 - Train Accuracy:  0.398, Validation Accuracy:  0.400, Loss:  1.252
# Epoch   0 Batch  313/538 - Train Accuracy:  0.338, Validation Accuracy:  0.398, Loss:  1.378
# Epoch   0 Batch  314/538 - Train Accuracy:  0.348, Validation Accuracy:  0.398, Loss:  1.344
# Epoch   0 Batch  315/538 - Train Accuracy:  0.355, Validation Accuracy:  0.396, Loss:  1.322
# Epoch   0 Batch  316/538 - Train Accuracy:  0.359, Validation Accuracy:  0.396, Loss:  1.317
# Epoch   0 Batch  317/538 - Train Accuracy:  0.333, Validation Accuracy:  0.395, Loss:  1.352
# Epoch   0 Batch  318/538 - Train Accuracy:  0.347, Validation Accuracy:  0.396, Loss:  1.302
# Epoch   0 Batch  319/538 - Train Accuracy:  0.366, Validation Accuracy:  0.397, Loss:  1.297
# Epoch   0 Batch  320/538 - Train Accuracy:  0.358, Validation Accuracy:  0.398, Loss:  1.306
# Epoch   0 Batch  321/538 - Train Accuracy:  0.362, Validation Accuracy:  0.396, Loss:  1.273
# Epoch   0 Batch  322/538 - Train Accuracy:  0.361, Validation Accuracy:  0.397, Loss:  1.325
# Epoch   0 Batch  323/538 - Train Accuracy:  0.352, Validation Accuracy:  0.397, Loss:  1.288
# Epoch   0 Batch  324/538 - Train Accuracy:  0.326, Validation Accuracy:  0.399, Loss:  1.366
# Epoch   0 Batch  325/538 - Train Accuracy:  0.350, Validation Accuracy:  0.400, Loss:  1.297
# Epoch   0 Batch  326/538 - Train Accuracy:  0.339, Validation Accuracy:  0.399, Loss:  1.301
# Epoch   0 Batch  327/538 - Train Accuracy:  0.333, Validation Accuracy:  0.399, Loss:  1.333
# Epoch   0 Batch  328/538 - Train Accuracy:  0.355, Validation Accuracy:  0.400, Loss:  1.255
# Epoch   0 Batch  329/538 - Train Accuracy:  0.358, Validation Accuracy:  0.398, Loss:  1.268
# Epoch   0 Batch  330/538 - Train Accuracy:  0.369, Validation Accuracy:  0.398, Loss:  1.242
# Epoch   0 Batch  331/538 - Train Accuracy:  0.326, Validation Accuracy:  0.399, Loss:  1.282
# Epoch   0 Batch  332/538 - Train Accuracy:  0.324, Validation Accuracy:  0.399, Loss:  1.296
# Epoch   0 Batch  333/538 - Train Accuracy:  0.365, Validation Accuracy:  0.400, Loss:  1.234
# Epoch   0 Batch  334/538 - Train Accuracy:  0.401, Validation Accuracy:  0.399, Loss:  1.169
# Epoch   0 Batch  335/538 - Train Accuracy:  0.366, Validation Accuracy:  0.399, Loss:  1.233
# Epoch   0 Batch  336/538 - Train Accuracy:  0.362, Validation Accuracy:  0.397, Loss:  1.235
# Epoch   0 Batch  337/538 - Train Accuracy:  0.360, Validation Accuracy:  0.398, Loss:  1.230
# Epoch   0 Batch  338/538 - Train Accuracy:  0.355, Validation Accuracy:  0.397, Loss:  1.244
# Epoch   0 Batch  339/538 - Train Accuracy:  0.363, Validation Accuracy:  0.396, Loss:  1.217
# Epoch   0 Batch  340/538 - Train Accuracy:  0.310, Validation Accuracy:  0.395, Loss:  1.288
# Epoch   0 Batch  341/538 - Train Accuracy:  0.328, Validation Accuracy:  0.398, Loss:  1.264
# Epoch   0 Batch  342/538 - Train Accuracy:  0.369, Validation Accuracy:  0.399, Loss:  1.219
# Epoch   0 Batch  343/538 - Train Accuracy:  0.342, Validation Accuracy:  0.398, Loss:  1.256
# Epoch   0 Batch  344/538 - Train Accuracy:  0.327, Validation Accuracy:  0.399, Loss:  1.234
# Epoch   0 Batch  345/538 - Train Accuracy:  0.359, Validation Accuracy:  0.399, Loss:  1.193
# Epoch   0 Batch  346/538 - Train Accuracy:  0.368, Validation Accuracy:  0.399, Loss:  1.224
# Epoch   0 Batch  347/538 - Train Accuracy:  0.344, Validation Accuracy:  0.398, Loss:  1.228
# Epoch   0 Batch  348/538 - Train Accuracy:  0.358, Validation Accuracy:  0.400, Loss:  1.202
# Epoch   0 Batch  349/538 - Train Accuracy:  0.326, Validation Accuracy:  0.400, Loss:  1.220
# Epoch   0 Batch  350/538 - Train Accuracy:  0.353, Validation Accuracy:  0.396, Loss:  1.221
# Epoch   0 Batch  351/538 - Train Accuracy:  0.322, Validation Accuracy:  0.396, Loss:  1.264
# Epoch   0 Batch  352/538 - Train Accuracy:  0.362, Validation Accuracy:  0.401, Loss:  1.171
# Epoch   0 Batch  353/538 - Train Accuracy:  0.346, Validation Accuracy:  0.401, Loss:  1.220
# Epoch   0 Batch  354/538 - Train Accuracy:  0.326, Validation Accuracy:  0.399, Loss:  1.237
# Epoch   0 Batch  355/538 - Train Accuracy:  0.331, Validation Accuracy:  0.398, Loss:  1.236
# Epoch   0 Batch  356/538 - Train Accuracy:  0.380, Validation Accuracy:  0.400, Loss:  1.139
# Epoch   0 Batch  357/538 - Train Accuracy:  0.343, Validation Accuracy:  0.402, Loss:  1.198
# Epoch   0 Batch  358/538 - Train Accuracy:  0.330, Validation Accuracy:  0.401, Loss:  1.188
# Epoch   0 Batch  359/538 - Train Accuracy:  0.367, Validation Accuracy:  0.401, Loss:  1.152
# Epoch   0 Batch  360/538 - Train Accuracy:  0.335, Validation Accuracy:  0.402, Loss:  1.210
# Epoch   0 Batch  361/538 - Train Accuracy:  0.360, Validation Accuracy:  0.402, Loss:  1.144
# Epoch   0 Batch  362/538 - Train Accuracy:  0.366, Validation Accuracy:  0.403, Loss:  1.115
# Epoch   0 Batch  363/538 - Train Accuracy:  0.385, Validation Accuracy:  0.402, Loss:  1.131
# Epoch   0 Batch  364/538 - Train Accuracy:  0.331, Validation Accuracy:  0.399, Loss:  1.199
# Epoch   0 Batch  365/538 - Train Accuracy:  0.361, Validation Accuracy:  0.401, Loss:  1.162
# Epoch   0 Batch  366/538 - Train Accuracy:  0.334, Validation Accuracy:  0.400, Loss:  1.173
# Epoch   0 Batch  367/538 - Train Accuracy:  0.330, Validation Accuracy:  0.398, Loss:  1.156
# Epoch   0 Batch  368/538 - Train Accuracy:  0.429, Validation Accuracy:  0.397, Loss:  1.000
# Epoch   0 Batch  369/538 - Train Accuracy:  0.331, Validation Accuracy:  0.398, Loss:  1.150
# Epoch   0 Batch  370/538 - Train Accuracy:  0.329, Validation Accuracy:  0.399, Loss:  1.177
# Epoch   0 Batch  371/538 - Train Accuracy:  0.372, Validation Accuracy:  0.399, Loss:  1.117
# Epoch   0 Batch  372/538 - Train Accuracy:  0.349, Validation Accuracy:  0.398, Loss:  1.136
# Epoch   0 Batch  373/538 - Train Accuracy:  0.329, Validation Accuracy:  0.398, Loss:  1.131
# Epoch   0 Batch  374/538 - Train Accuracy:  0.329, Validation Accuracy:  0.400, Loss:  1.157
# Epoch   0 Batch  375/538 - Train Accuracy:  0.376, Validation Accuracy:  0.400, Loss:  1.064
# Epoch   0 Batch  376/538 - Train Accuracy:  0.335, Validation Accuracy:  0.400, Loss:  1.145
# Epoch   0 Batch  377/538 - Train Accuracy:  0.351, Validation Accuracy:  0.396, Loss:  1.106
# Epoch   0 Batch  378/538 - Train Accuracy:  0.369, Validation Accuracy:  0.398, Loss:  1.064
# Epoch   0 Batch  379/538 - Train Accuracy:  0.376, Validation Accuracy:  0.402, Loss:  1.087
# Epoch   0 Batch  380/538 - Train Accuracy:  0.347, Validation Accuracy:  0.403, Loss:  1.114
# Epoch   0 Batch  381/538 - Train Accuracy:  0.370, Validation Accuracy:  0.401, Loss:  1.065
# Epoch   0 Batch  382/538 - Train Accuracy:  0.327, Validation Accuracy:  0.398, Loss:  1.126
# Epoch   0 Batch  383/538 - Train Accuracy:  0.333, Validation Accuracy:  0.398, Loss:  1.112
# Epoch   0 Batch  384/538 - Train Accuracy:  0.363, Validation Accuracy:  0.400, Loss:  1.093
# Epoch   0 Batch  385/538 - Train Accuracy:  0.356, Validation Accuracy:  0.401, Loss:  1.085
# Epoch   0 Batch  386/538 - Train Accuracy:  0.345, Validation Accuracy:  0.401, Loss:  1.123
# Epoch   0 Batch  387/538 - Train Accuracy:  0.335, Validation Accuracy:  0.399, Loss:  1.121
# Epoch   0 Batch  388/538 - Train Accuracy:  0.357, Validation Accuracy:  0.399, Loss:  1.071
# Epoch   0 Batch  389/538 - Train Accuracy:  0.339, Validation Accuracy:  0.400, Loss:  1.141
# Epoch   0 Batch  390/538 - Train Accuracy:  0.344, Validation Accuracy:  0.399, Loss:  1.056
# Epoch   0 Batch  391/538 - Train Accuracy:  0.356, Validation Accuracy:  0.399, Loss:  1.073
# Epoch   0 Batch  392/538 - Train Accuracy:  0.344, Validation Accuracy:  0.401, Loss:  1.070
# Epoch   0 Batch  393/538 - Train Accuracy:  0.376, Validation Accuracy:  0.401, Loss:  1.025
# Epoch   0 Batch  394/538 - Train Accuracy:  0.322, Validation Accuracy:  0.401, Loss:  1.124
# Epoch   0 Batch  395/538 - Train Accuracy:  0.333, Validation Accuracy:  0.398, Loss:  1.107
# Epoch   0 Batch  396/538 - Train Accuracy:  0.326, Validation Accuracy:  0.397, Loss:  1.070
# Epoch   0 Batch  397/538 - Train Accuracy:  0.323, Validation Accuracy:  0.399, Loss:  1.123
# Epoch   0 Batch  398/538 - Train Accuracy:  0.318, Validation Accuracy:  0.399, Loss:  1.099
# Epoch   0 Batch  399/538 - Train Accuracy:  0.323, Validation Accuracy:  0.400, Loss:  1.120
# Epoch   0 Batch  400/538 - Train Accuracy:  0.351, Validation Accuracy:  0.398, Loss:  1.051
# Epoch   0 Batch  401/538 - Train Accuracy:  0.327, Validation Accuracy:  0.396, Loss:  1.086
# Epoch   0 Batch  402/538 - Train Accuracy:  0.340, Validation Accuracy:  0.395, Loss:  1.051
# Epoch   0 Batch  403/538 - Train Accuracy:  0.322, Validation Accuracy:  0.394, Loss:  1.092
# Epoch   0 Batch  404/538 - Train Accuracy:  0.358, Validation Accuracy:  0.392, Loss:  1.017
# Epoch   0 Batch  405/538 - Train Accuracy:  0.350, Validation Accuracy:  0.395, Loss:  1.028
# Epoch   0 Batch  406/538 - Train Accuracy:  0.355, Validation Accuracy:  0.399, Loss:  1.033
# Epoch   0 Batch  407/538 - Train Accuracy:  0.342, Validation Accuracy:  0.397, Loss:  1.040
# Epoch   0 Batch  408/538 - Train Accuracy:  0.324, Validation Accuracy:  0.394, Loss:  1.112
# Epoch   0 Batch  409/538 - Train Accuracy:  0.306, Validation Accuracy:  0.392, Loss:  1.069
# Epoch   0 Batch  410/538 - Train Accuracy:  0.343, Validation Accuracy:  0.393, Loss:  1.045
# Epoch   0 Batch  411/538 - Train Accuracy:  0.356, Validation Accuracy:  0.395, Loss:  1.012
# Epoch   0 Batch  412/538 - Train Accuracy:  0.347, Validation Accuracy:  0.397, Loss:  0.992
# Epoch   0 Batch  413/538 - Train Accuracy:  0.313, Validation Accuracy:  0.397, Loss:  1.074
# Epoch   0 Batch  414/538 - Train Accuracy:  0.333, Validation Accuracy:  0.398, Loss:  1.054
# Epoch   0 Batch  415/538 - Train Accuracy:  0.311, Validation Accuracy:  0.400, Loss:  1.064
# Epoch   0 Batch  416/538 - Train Accuracy:  0.383, Validation Accuracy:  0.399, Loss:  0.975
# Epoch   0 Batch  417/538 - Train Accuracy:  0.333, Validation Accuracy:  0.397, Loss:  1.055
# Epoch   0 Batch  418/538 - Train Accuracy:  0.330, Validation Accuracy:  0.396, Loss:  1.059
# Epoch   0 Batch  419/538 - Train Accuracy:  0.327, Validation Accuracy:  0.400, Loss:  1.017
# Epoch   0 Batch  420/538 - Train Accuracy:  0.325, Validation Accuracy:  0.398, Loss:  1.015
# Epoch   0 Batch  421/538 - Train Accuracy:  0.351, Validation Accuracy:  0.395, Loss:  0.996
# Epoch   0 Batch  422/538 - Train Accuracy:  0.336, Validation Accuracy:  0.396, Loss:  1.014
# Epoch   0 Batch  423/538 - Train Accuracy:  0.336, Validation Accuracy:  0.398, Loss:  1.031
# Epoch   0 Batch  424/538 - Train Accuracy:  0.348, Validation Accuracy:  0.398, Loss:  1.008
# Epoch   0 Batch  425/538 - Train Accuracy:  0.366, Validation Accuracy:  0.399, Loss:  0.986
# Epoch   0 Batch  426/538 - Train Accuracy:  0.347, Validation Accuracy:  0.400, Loss:  0.991
# Epoch   0 Batch  427/538 - Train Accuracy:  0.323, Validation Accuracy:  0.398, Loss:  1.021
# Epoch   0 Batch  428/538 - Train Accuracy:  0.365, Validation Accuracy:  0.401, Loss:  0.969
# Epoch   0 Batch  429/538 - Train Accuracy:  0.361, Validation Accuracy:  0.400, Loss:  0.977
# Epoch   0 Batch  430/538 - Train Accuracy:  0.330, Validation Accuracy:  0.398, Loss:  1.000
# Epoch   0 Batch  431/538 - Train Accuracy:  0.341, Validation Accuracy:  0.398, Loss:  0.994
# Epoch   0 Batch  432/538 - Train Accuracy:  0.395, Validation Accuracy:  0.398, Loss:  0.918
# Epoch   0 Batch  433/538 - Train Accuracy:  0.329, Validation Accuracy:  0.399, Loss:  1.035
# Epoch   0 Batch  434/538 - Train Accuracy:  0.324, Validation Accuracy:  0.399, Loss:  1.046
# Epoch   0 Batch  435/538 - Train Accuracy:  0.324, Validation Accuracy:  0.398, Loss:  0.994
# Epoch   0 Batch  436/538 - Train Accuracy:  0.328, Validation Accuracy:  0.398, Loss:  1.019
# Epoch   0 Batch  437/538 - Train Accuracy:  0.323, Validation Accuracy:  0.400, Loss:  1.026
# Epoch   0 Batch  438/538 - Train Accuracy:  0.341, Validation Accuracy:  0.400, Loss:  0.983
# Epoch   0 Batch  439/538 - Train Accuracy:  0.346, Validation Accuracy:  0.399, Loss:  0.964
# Epoch   0 Batch  440/538 - Train Accuracy:  0.325, Validation Accuracy:  0.398, Loss:  1.026
# Epoch   0 Batch  441/538 - Train Accuracy:  0.320, Validation Accuracy:  0.401, Loss:  1.031
# Epoch   0 Batch  442/538 - Train Accuracy:  0.376, Validation Accuracy:  0.400, Loss:  0.903
# Epoch   0 Batch  443/538 - Train Accuracy:  0.358, Validation Accuracy:  0.401, Loss:  0.976
# Epoch   0 Batch  444/538 - Train Accuracy:  0.377, Validation Accuracy:  0.401, Loss:  0.914
# Epoch   0 Batch  445/538 - Train Accuracy:  0.336, Validation Accuracy:  0.400, Loss:  0.964
# Epoch   0 Batch  446/538 - Train Accuracy:  0.375, Validation Accuracy:  0.399, Loss:  0.912
# Epoch   0 Batch  447/538 - Train Accuracy:  0.314, Validation Accuracy:  0.398, Loss:  0.981
# Epoch   0 Batch  448/538 - Train Accuracy:  0.367, Validation Accuracy:  0.396, Loss:  0.907
# Epoch   0 Batch  449/538 - Train Accuracy:  0.328, Validation Accuracy:  0.397, Loss:  1.001
# Epoch   0 Batch  450/538 - Train Accuracy:  0.366, Validation Accuracy:  0.397, Loss:  0.968
# Epoch   0 Batch  451/538 - Train Accuracy:  0.329, Validation Accuracy:  0.397, Loss:  0.966
# Epoch   0 Batch  452/538 - Train Accuracy:  0.329, Validation Accuracy:  0.398, Loss:  0.954
# Epoch   0 Batch  453/538 - Train Accuracy:  0.333, Validation Accuracy:  0.397, Loss:  0.978
# Epoch   0 Batch  454/538 - Train Accuracy:  0.361, Validation Accuracy:  0.396, Loss:  0.934
# Epoch   0 Batch  455/538 - Train Accuracy:  0.392, Validation Accuracy:  0.396, Loss:  0.882
# Epoch   0 Batch  456/538 - Train Accuracy:  0.447, Validation Accuracy:  0.398, Loss:  0.840
# Epoch   0 Batch  457/538 - Train Accuracy:  0.317, Validation Accuracy:  0.398, Loss:  0.975
# Epoch   0 Batch  458/538 - Train Accuracy:  0.356, Validation Accuracy:  0.397, Loss:  0.930
# Epoch   0 Batch  459/538 - Train Accuracy:  0.333, Validation Accuracy:  0.398, Loss:  0.946
# Epoch   0 Batch  460/538 - Train Accuracy:  0.363, Validation Accuracy:  0.397, Loss:  0.932
# Epoch   0 Batch  461/538 - Train Accuracy:  0.289, Validation Accuracy:  0.396, Loss:  1.013
# Epoch   0 Batch  462/538 - Train Accuracy:  0.342, Validation Accuracy:  0.395, Loss:  0.937
# Epoch   0 Batch  463/538 - Train Accuracy:  0.333, Validation Accuracy:  0.397, Loss:  0.961
# Epoch   0 Batch  464/538 - Train Accuracy:  0.325, Validation Accuracy:  0.398, Loss:  0.974
# Epoch   0 Batch  465/538 - Train Accuracy:  0.322, Validation Accuracy:  0.396, Loss:  0.957
# Epoch   0 Batch  466/538 - Train Accuracy:  0.304, Validation Accuracy:  0.396, Loss:  0.958
# Epoch   0 Batch  467/538 - Train Accuracy:  0.344, Validation Accuracy:  0.397, Loss:  0.926
# Epoch   0 Batch  468/538 - Train Accuracy:  0.338, Validation Accuracy:  0.397, Loss:  0.965
# Epoch   0 Batch  469/538 - Train Accuracy:  0.324, Validation Accuracy:  0.396, Loss:  0.962
# Epoch   0 Batch  470/538 - Train Accuracy:  0.353, Validation Accuracy:  0.398, Loss:  0.909
# Epoch   0 Batch  471/538 - Train Accuracy:  0.356, Validation Accuracy:  0.398, Loss:  0.923
# Epoch   0 Batch  472/538 - Train Accuracy:  0.334, Validation Accuracy:  0.398, Loss:  0.928
# Epoch   0 Batch  473/538 - Train Accuracy:  0.328, Validation Accuracy:  0.399, Loss:  0.959
# Epoch   0 Batch  474/538 - Train Accuracy:  0.358, Validation Accuracy:  0.399, Loss:  0.893
# Epoch   0 Batch  475/538 - Train Accuracy:  0.373, Validation Accuracy:  0.399, Loss:  0.898
# Epoch   0 Batch  476/538 - Train Accuracy:  0.321, Validation Accuracy:  0.400, Loss:  0.942
# Epoch   0 Batch  477/538 - Train Accuracy:  0.339, Validation Accuracy:  0.400, Loss:  0.935
# Epoch   0 Batch  478/538 - Train Accuracy:  0.350, Validation Accuracy:  0.399, Loss:  0.893
# Epoch   0 Batch  479/538 - Train Accuracy:  0.368, Validation Accuracy:  0.399, Loss:  0.877
# Epoch   0 Batch  480/538 - Train Accuracy:  0.359, Validation Accuracy:  0.399, Loss:  0.892
# Epoch   0 Batch  481/538 - Train Accuracy:  0.355, Validation Accuracy:  0.398, Loss:  0.907
# Epoch   0 Batch  482/538 - Train Accuracy:  0.400, Validation Accuracy:  0.398, Loss:  0.822
# Epoch   0 Batch  483/538 - Train Accuracy:  0.343, Validation Accuracy:  0.398, Loss:  0.926
# Epoch   0 Batch  484/538 - Train Accuracy:  0.363, Validation Accuracy:  0.397, Loss:  0.900
# Epoch   0 Batch  485/538 - Train Accuracy:  0.358, Validation Accuracy:  0.395, Loss:  0.893
# Epoch   0 Batch  486/538 - Train Accuracy:  0.338, Validation Accuracy:  0.396, Loss:  0.876
# Epoch   0 Batch  487/538 - Train Accuracy:  0.360, Validation Accuracy:  0.395, Loss:  0.868
# Epoch   0 Batch  488/538 - Train Accuracy:  0.351, Validation Accuracy:  0.396, Loss:  0.887
# Epoch   0 Batch  489/538 - Train Accuracy:  0.322, Validation Accuracy:  0.397, Loss:  0.928
# Epoch   0 Batch  490/538 - Train Accuracy:  0.359, Validation Accuracy:  0.396, Loss:  0.878
# Epoch   0 Batch  491/538 - Train Accuracy:  0.323, Validation Accuracy:  0.395, Loss:  0.931
# Epoch   0 Batch  492/538 - Train Accuracy:  0.336, Validation Accuracy:  0.398, Loss:  0.922
# Epoch   0 Batch  493/538 - Train Accuracy:  0.347, Validation Accuracy:  0.399, Loss:  0.888
# Epoch   0 Batch  494/538 - Train Accuracy:  0.338, Validation Accuracy:  0.399, Loss:  0.928
# Epoch   0 Batch  495/538 - Train Accuracy:  0.331, Validation Accuracy:  0.396, Loss:  0.917
# Epoch   0 Batch  496/538 - Train Accuracy:  0.327, Validation Accuracy:  0.395, Loss:  0.900
# Epoch   0 Batch  497/538 - Train Accuracy:  0.357, Validation Accuracy:  0.393, Loss:  0.879
# Epoch   0 Batch  498/538 - Train Accuracy:  0.316, Validation Accuracy:  0.396, Loss:  0.893
# Epoch   0 Batch  499/538 - Train Accuracy:  0.365, Validation Accuracy:  0.397, Loss:  0.871
# Epoch   0 Batch  500/538 - Train Accuracy:  0.379, Validation Accuracy:  0.398, Loss:  0.829
# Epoch   0 Batch  501/538 - Train Accuracy:  0.358, Validation Accuracy:  0.400, Loss:  0.892
# Epoch   0 Batch  502/538 - Train Accuracy:  0.319, Validation Accuracy:  0.400, Loss:  0.891
# Epoch   0 Batch  503/538 - Train Accuracy:  0.364, Validation Accuracy:  0.401, Loss:  0.849
# Epoch   0 Batch  504/538 - Train Accuracy:  0.326, Validation Accuracy:  0.398, Loss:  0.891
# Epoch   0 Batch  505/538 - Train Accuracy:  0.338, Validation Accuracy:  0.398, Loss:  0.876
# Epoch   0 Batch  506/538 - Train Accuracy:  0.343, Validation Accuracy:  0.398, Loss:  0.862
# Epoch   0 Batch  507/538 - Train Accuracy:  0.343, Validation Accuracy:  0.398, Loss:  0.895
# Epoch   0 Batch  508/538 - Train Accuracy:  0.367, Validation Accuracy:  0.398, Loss:  0.833
# Epoch   0 Batch  509/538 - Train Accuracy:  0.331, Validation Accuracy:  0.397, Loss:  0.885
# Epoch   0 Batch  510/538 - Train Accuracy:  0.362, Validation Accuracy:  0.395, Loss:  0.852
# Epoch   0 Batch  511/538 - Train Accuracy:  0.388, Validation Accuracy:  0.395, Loss:  0.829
# Epoch   0 Batch  512/538 - Train Accuracy:  0.364, Validation Accuracy:  0.397, Loss:  0.843
# Epoch   0 Batch  513/538 - Train Accuracy:  0.338, Validation Accuracy:  0.394, Loss:  0.882
# Epoch   0 Batch  514/538 - Train Accuracy:  0.313, Validation Accuracy:  0.394, Loss:  0.888
# Epoch   0 Batch  515/538 - Train Accuracy:  0.362, Validation Accuracy:  0.396, Loss:  0.848
# ...
# Epoch   2 Batch  366/538 - Train Accuracy:  0.354, Validation Accuracy:  0.419, Loss:  0.279
# Epoch   2 Batch  367/538 - Train Accuracy:  0.353, Validation Accuracy:  0.421, Loss:  0.268
# Epoch   2 Batch  368/538 - Train Accuracy:  0.448, Validation Accuracy:  0.421, Loss:  0.242
# Epoch   2 Batch  369/538 - Train Accuracy:  0.356, Validation Accuracy:  0.421, Loss:  0.262
# Epoch   2 Batch  370/538 - Train Accuracy:  0.346, Validation Accuracy:  0.420, Loss:  0.281
# Epoch   2 Batch  371/538 - Train Accuracy:  0.387, Validation Accuracy:  0.420, Loss:  0.261
# Epoch   2 Batch  372/538 - Train Accuracy:  0.373, Validation Accuracy:  0.418, Loss:  0.269
# Epoch   2 Batch  373/538 - Train Accuracy:  0.356, Validation Accuracy:  0.417, Loss:  0.252
# Epoch   2 Batch  374/538 - Train Accuracy:  0.356, Validation Accuracy:  0.418, Loss:  0.273
# Epoch   2 Batch  375/538 - Train Accuracy:  0.394, Validation Accuracy:  0.418, Loss:  0.243
# Epoch   2 Batch  376/538 - Train Accuracy:  0.355, Validation Accuracy:  0.419, Loss:  0.269
# Epoch   2 Batch  377/538 - Train Accuracy:  0.369, Validation Accuracy:  0.420, Loss:  0.254
# Epoch   2 Batch  378/538 - Train Accuracy:  0.394, Validation Accuracy:  0.421, Loss:  0.255
# Epoch   2 Batch  379/538 - Train Accuracy:  0.393, Validation Accuracy:  0.421, Loss:  0.256
# Epoch   2 Batch  380/538 - Train Accuracy:  0.369, Validation Accuracy:  0.423, Loss:  0.257
# Epoch   2 Batch  381/538 - Train Accuracy:  0.394, Validation Accuracy:  0.423, Loss:  0.247
# Epoch   2 Batch  382/538 - Train Accuracy:  0.355, Validation Accuracy:  0.423, Loss:  0.261
# Epoch   2 Batch  383/538 - Train Accuracy:  0.360, Validation Accuracy:  0.422, Loss:  0.266
# Epoch   2 Batch  384/538 - Train Accuracy:  0.380, Validation Accuracy:  0.420, Loss:  0.259
# Epoch   2 Batch  385/538 - Train Accuracy:  0.384, Validation Accuracy:  0.420, Loss:  0.261
# Epoch   2 Batch  386/538 - Train Accuracy:  0.367, Validation Accuracy:  0.421, Loss:  0.275
# Epoch   2 Batch  387/538 - Train Accuracy:  0.356, Validation Accuracy:  0.422, Loss:  0.265
# Epoch   2 Batch  388/538 - Train Accuracy:  0.379, Validation Accuracy:  0.421, Loss:  0.261
# Epoch   2 Batch  389/538 - Train Accuracy:  0.363, Validation Accuracy:  0.424, Loss:  0.281
# Epoch   2 Batch  390/538 - Train Accuracy:  0.377, Validation Accuracy:  0.423, Loss:  0.251
# Epoch   2 Batch  391/538 - Train Accuracy:  0.385, Validation Accuracy:  0.422, Loss:  0.255
# Epoch   2 Batch  392/538 - Train Accuracy:  0.368, Validation Accuracy:  0.423, Loss:  0.256
# Epoch   2 Batch  393/538 - Train Accuracy:  0.392, Validation Accuracy:  0.422, Loss:  0.243
# Epoch   2 Batch  394/538 - Train Accuracy:  0.336, Validation Accuracy:  0.421, Loss:  0.263
# Epoch   2 Batch  395/538 - Train Accuracy:  0.358, Validation Accuracy:  0.422, Loss:  0.274
# Epoch   2 Batch  396/538 - Train Accuracy:  0.355, Validation Accuracy:  0.423, Loss:  0.257
# Epoch   2 Batch  397/538 - Train Accuracy:  0.347, Validation Accuracy:  0.423, Loss:  0.273
# Epoch   2 Batch  398/538 - Train Accuracy:  0.338, Validation Accuracy:  0.422, Loss:  0.263
# Epoch   2 Batch  399/538 - Train Accuracy:  0.343, Validation Accuracy:  0.421, Loss:  0.278
# Epoch   2 Batch  400/538 - Train Accuracy:  0.375, Validation Accuracy:  0.419, Loss:  0.256
# Epoch   2 Batch  401/538 - Train Accuracy:  0.350, Validation Accuracy:  0.420, Loss:  0.265
# Epoch   2 Batch  402/538 - Train Accuracy:  0.365, Validation Accuracy:  0.420, Loss:  0.254
# Epoch   2 Batch  403/538 - Train Accuracy:  0.348, Validation Accuracy:  0.421, Loss:  0.265
# Epoch   2 Batch  404/538 - Train Accuracy:  0.385, Validation Accuracy:  0.422, Loss:  0.252
# Epoch   2 Batch  405/538 - Train Accuracy:  0.371, Validation Accuracy:  0.420, Loss:  0.249
# Epoch   2 Batch  406/538 - Train Accuracy:  0.371, Validation Accuracy:  0.420, Loss:  0.247
# Epoch   2 Batch  407/538 - Train Accuracy:  0.360, Validation Accuracy:  0.420, Loss:  0.254
# Epoch   2 Batch  408/538 - Train Accuracy:  0.349, Validation Accuracy:  0.419, Loss:  0.271
# Epoch   2 Batch  409/538 - Train Accuracy:  0.329, Validation Accuracy:  0.419, Loss:  0.266
# Epoch   2 Batch  410/538 - Train Accuracy:  0.360, Validation Accuracy:  0.419, Loss:  0.258
# Epoch   2 Batch  411/538 - Train Accuracy:  0.375, Validation Accuracy:  0.419, Loss:  0.242
# Epoch   2 Batch  412/538 - Train Accuracy:  0.374, Validation Accuracy:  0.420, Loss:  0.242
# Epoch   2 Batch  413/538 - Train Accuracy:  0.338, Validation Accuracy:  0.419, Loss:  0.264
# Epoch   2 Batch  414/538 - Train Accuracy:  0.356, Validation Accuracy:  0.418, Loss:  0.256
# Epoch   2 Batch  415/538 - Train Accuracy:  0.343, Validation Accuracy:  0.419, Loss:  0.257
# Epoch   2 Batch  416/538 - Train Accuracy:  0.405, Validation Accuracy:  0.420, Loss:  0.250
# Epoch   2 Batch  417/538 - Train Accuracy:  0.356, Validation Accuracy:  0.419, Loss:  0.253
# Epoch   2 Batch  418/538 - Train Accuracy:  0.345, Validation Accuracy:  0.419, Loss:  0.261
# Epoch   2 Batch  419/538 - Train Accuracy:  0.345, Validation Accuracy:  0.419, Loss:  0.242
# Epoch   2 Batch  420/538 - Train Accuracy:  0.353, Validation Accuracy:  0.419, Loss:  0.253
# Epoch   2 Batch  421/538 - Train Accuracy:  0.374, Validation Accuracy:  0.418, Loss:  0.235
# Epoch   2 Batch  422/538 - Train Accuracy:  0.365, Validation Accuracy:  0.421, Loss:  0.251
# Epoch   2 Batch  423/538 - Train Accuracy:  0.364, Validation Accuracy:  0.421, Loss:  0.255
# Epoch   2 Batch  424/538 - Train Accuracy:  0.370, Validation Accuracy:  0.420, Loss:  0.251
# Epoch   2 Batch  425/538 - Train Accuracy:  0.385, Validation Accuracy:  0.421, Loss:  0.253
# Epoch   2 Batch  426/538 - Train Accuracy:  0.373, Validation Accuracy:  0.422, Loss:  0.243
# Epoch   2 Batch  427/538 - Train Accuracy:  0.357, Validation Accuracy:  0.421, Loss:  0.258
# Epoch   2 Batch  428/538 - Train Accuracy:  0.391, Validation Accuracy:  0.422, Loss:  0.232
# Epoch   2 Batch  429/538 - Train Accuracy:  0.394, Validation Accuracy:  0.422, Loss:  0.253
# Epoch   2 Batch  430/538 - Train Accuracy:  0.362, Validation Accuracy:  0.421, Loss:  0.243
# Epoch   2 Batch  431/538 - Train Accuracy:  0.370, Validation Accuracy:  0.420, Loss:  0.247
# Epoch   2 Batch  432/538 - Train Accuracy:  0.420, Validation Accuracy:  0.420, Loss:  0.231
# Epoch   2 Batch  433/538 - Train Accuracy:  0.353, Validation Accuracy:  0.422, Loss:  0.268
# Epoch   2 Batch  434/538 - Train Accuracy:  0.348, Validation Accuracy:  0.421, Loss:  0.258
# Epoch   2 Batch  435/538 - Train Accuracy:  0.349, Validation Accuracy:  0.420, Loss:  0.238
# Epoch   2 Batch  436/538 - Train Accuracy:  0.351, Validation Accuracy:  0.419, Loss:  0.258
# Epoch   2 Batch  437/538 - Train Accuracy:  0.349, Validation Accuracy:  0.418, Loss:  0.251
# Epoch   2 Batch  438/538 - Train Accuracy:  0.353, Validation Accuracy:  0.416, Loss:  0.241
# Epoch   2 Batch  439/538 - Train Accuracy:  0.361, Validation Accuracy:  0.416, Loss:  0.236
# Epoch   2 Batch  440/538 - Train Accuracy:  0.344, Validation Accuracy:  0.418, Loss:  0.260
# Epoch   2 Batch  441/538 - Train Accuracy:  0.346, Validation Accuracy:  0.417, Loss:  0.256
# Epoch   2 Batch  442/538 - Train Accuracy:  0.400, Validation Accuracy:  0.417, Loss:  0.218
# Epoch   2 Batch  443/538 - Train Accuracy:  0.378, Validation Accuracy:  0.419, Loss:  0.247
# Epoch   2 Batch  444/538 - Train Accuracy:  0.395, Validation Accuracy:  0.420, Loss:  0.228
# Epoch   2 Batch  445/538 - Train Accuracy:  0.358, Validation Accuracy:  0.419, Loss:  0.234
# Epoch   2 Batch  446/538 - Train Accuracy:  0.399, Validation Accuracy:  0.420, Loss:  0.227
# Epoch   2 Batch  447/538 - Train Accuracy:  0.344, Validation Accuracy:  0.420, Loss:  0.246
# Epoch   2 Batch  448/538 - Train Accuracy:  0.394, Validation Accuracy:  0.420, Loss:  0.223
# Epoch   2 Batch  449/538 - Train Accuracy:  0.356, Validation Accuracy:  0.418, Loss:  0.251
# Epoch   2 Batch  450/538 - Train Accuracy:  0.387, Validation Accuracy:  0.420, Loss:  0.252
# Epoch   2 Batch  451/538 - Train Accuracy:  0.355, Validation Accuracy:  0.421, Loss:  0.242
# Epoch   2 Batch  452/538 - Train Accuracy:  0.360, Validation Accuracy:  0.420, Loss:  0.233
# Epoch   2 Batch  453/538 - Train Accuracy:  0.356, Validation Accuracy:  0.420, Loss:  0.243
# Epoch   2 Batch  454/538 - Train Accuracy:  0.389, Validation Accuracy:  0.420, Loss:  0.233
# Epoch   2 Batch  455/538 - Train Accuracy:  0.410, Validation Accuracy:  0.420, Loss:  0.221
# Epoch   2 Batch  456/538 - Train Accuracy:  0.467, Validation Accuracy:  0.418, Loss:  0.228
# Epoch   2 Batch  457/538 - Train Accuracy:  0.345, Validation Accuracy:  0.419, Loss:  0.252
# Epoch   2 Batch  458/538 - Train Accuracy:  0.387, Validation Accuracy:  0.421, Loss:  0.226
# Epoch   2 Batch  459/538 - Train Accuracy:  0.371, Validation Accuracy:  0.422, Loss:  0.230
# Epoch   2 Batch  460/538 - Train Accuracy:  0.386, Validation Accuracy:  0.421, Loss:  0.236
# Epoch   2 Batch  461/538 - Train Accuracy:  0.322, Validation Accuracy:  0.420, Loss:  0.253
# Epoch   2 Batch  462/538 - Train Accuracy:  0.372, Validation Accuracy:  0.420, Loss:  0.225
# Epoch   2 Batch  463/538 - Train Accuracy:  0.354, Validation Accuracy:  0.419, Loss:  0.241
# Epoch   2 Batch  464/538 - Train Accuracy:  0.355, Validation Accuracy:  0.419, Loss:  0.236
# Epoch   2 Batch  465/538 - Train Accuracy:  0.350, Validation Accuracy:  0.419, Loss:  0.229
# Epoch   2 Batch  466/538 - Train Accuracy:  0.324, Validation Accuracy:  0.420, Loss:  0.234
# Epoch   2 Batch  467/538 - Train Accuracy:  0.366, Validation Accuracy:  0.419, Loss:  0.237
# Epoch   2 Batch  468/538 - Train Accuracy:  0.361, Validation Accuracy:  0.418, Loss:  0.247
# Epoch   2 Batch  469/538 - Train Accuracy:  0.355, Validation Accuracy:  0.418, Loss:  0.235
# Epoch   2 Batch  470/538 - Train Accuracy:  0.381, Validation Accuracy:  0.417, Loss:  0.228
# Epoch   2 Batch  471/538 - Train Accuracy:  0.377, Validation Accuracy:  0.415, Loss:  0.226
# Epoch   2 Batch  472/538 - Train Accuracy:  0.359, Validation Accuracy:  0.416, Loss:  0.226
# Epoch   2 Batch  473/538 - Train Accuracy:  0.357, Validation Accuracy:  0.417, Loss:  0.232
# Epoch   2 Batch  474/538 - Train Accuracy:  0.381, Validation Accuracy:  0.417, Loss:  0.215
# Epoch   2 Batch  475/538 - Train Accuracy:  0.394, Validation Accuracy:  0.418, Loss:  0.224
# Epoch   2 Batch  476/538 - Train Accuracy:  0.337, Validation Accuracy:  0.419, Loss:  0.236
# Epoch   2 Batch  477/538 - Train Accuracy:  0.366, Validation Accuracy:  0.419, Loss:  0.231
# Epoch   2 Batch  478/538 - Train Accuracy:  0.376, Validation Accuracy:  0.420, Loss:  0.223
# Epoch   2 Batch  479/538 - Train Accuracy:  0.396, Validation Accuracy:  0.419, Loss:  0.217
# Epoch   2 Batch  480/538 - Train Accuracy:  0.379, Validation Accuracy:  0.419, Loss:  0.228
# Epoch   2 Batch  481/538 - Train Accuracy:  0.385, Validation Accuracy:  0.419, Loss:  0.227
# Epoch   2 Batch  482/538 - Train Accuracy:  0.425, Validation Accuracy:  0.420, Loss:  0.207
# Epoch   2 Batch  483/538 - Train Accuracy:  0.362, Validation Accuracy:  0.419, Loss:  0.245
# Epoch   2 Batch  484/538 - Train Accuracy:  0.395, Validation Accuracy:  0.418, Loss:  0.235
# Epoch   2 Batch  485/538 - Train Accuracy:  0.381, Validation Accuracy:  0.418, Loss:  0.222
# Epoch   2 Batch  486/538 - Train Accuracy:  0.372, Validation Accuracy:  0.419, Loss:  0.207
# Epoch   2 Batch  487/538 - Train Accuracy:  0.382, Validation Accuracy:  0.419, Loss:  0.213
# Epoch   2 Batch  488/538 - Train Accuracy:  0.371, Validation Accuracy:  0.419, Loss:  0.222
# Epoch   2 Batch  489/538 - Train Accuracy:  0.350, Validation Accuracy:  0.419, Loss:  0.239
# Epoch   2 Batch  490/538 - Train Accuracy:  0.378, Validation Accuracy:  0.420, Loss:  0.214
# Epoch   2 Batch  491/538 - Train Accuracy:  0.340, Validation Accuracy:  0.418, Loss:  0.237
# Epoch   2 Batch  492/538 - Train Accuracy:  0.359, Validation Accuracy:  0.417, Loss:  0.231
# Epoch   2 Batch  493/538 - Train Accuracy:  0.375, Validation Accuracy:  0.419, Loss:  0.211
# Epoch   2 Batch  494/538 - Train Accuracy:  0.361, Validation Accuracy:  0.419, Loss:  0.234
# Epoch   2 Batch  495/538 - Train Accuracy:  0.356, Validation Accuracy:  0.419, Loss:  0.226
# Epoch   2 Batch  496/538 - Train Accuracy:  0.354, Validation Accuracy:  0.420, Loss:  0.217
# Epoch   2 Batch  497/538 - Train Accuracy:  0.386, Validation Accuracy:  0.420, Loss:  0.219
# Epoch   2 Batch  498/538 - Train Accuracy:  0.349, Validation Accuracy:  0.419, Loss:  0.214
# Epoch   2 Batch  499/538 - Train Accuracy:  0.394, Validation Accuracy:  0.420, Loss:  0.218
# Epoch   2 Batch  500/538 - Train Accuracy:  0.401, Validation Accuracy:  0.420, Loss:  0.204
# Epoch   2 Batch  501/538 - Train Accuracy:  0.382, Validation Accuracy:  0.418, Loss:  0.225
# Epoch   2 Batch  502/538 - Train Accuracy:  0.342, Validation Accuracy:  0.421, Loss:  0.219
# Epoch   2 Batch  503/538 - Train Accuracy:  0.395, Validation Accuracy:  0.421, Loss:  0.223
# Epoch   2 Batch  504/538 - Train Accuracy:  0.352, Validation Accuracy:  0.420, Loss:  0.216
# Epoch   2 Batch  505/538 - Train Accuracy:  0.369, Validation Accuracy:  0.420, Loss:  0.213
# Epoch   2 Batch  506/538 - Train Accuracy:  0.371, Validation Accuracy:  0.420, Loss:  0.219
# Epoch   2 Batch  507/538 - Train Accuracy:  0.365, Validation Accuracy:  0.419, Loss:  0.234
# Epoch   2 Batch  508/538 - Train Accuracy:  0.394, Validation Accuracy:  0.419, Loss:  0.219
# Epoch   2 Batch  509/538 - Train Accuracy:  0.362, Validation Accuracy:  0.418, Loss:  0.232
# Epoch   2 Batch  510/538 - Train Accuracy:  0.387, Validation Accuracy:  0.418, Loss:  0.210
# Epoch   2 Batch  511/538 - Train Accuracy:  0.411, Validation Accuracy:  0.417, Loss:  0.215
# Epoch   2 Batch  512/538 - Train Accuracy:  0.385, Validation Accuracy:  0.418, Loss:  0.227
# Epoch   2 Batch  513/538 - Train Accuracy:  0.357, Validation Accuracy:  0.419, Loss:  0.218
# Epoch   2 Batch  514/538 - Train Accuracy:  0.340, Validation Accuracy:  0.421, Loss:  0.218
# Epoch   2 Batch  515/538 - Train Accuracy:  0.383, Validation Accuracy:  0.421, Loss:  0.225
# Epoch   2 Batch  516/538 - Train Accuracy:  0.367, Validation Accuracy:  0.421, Loss:  0.218
# Epoch   2 Batch  517/538 - Train Accuracy:  0.372, Validation Accuracy:  0.420, Loss:  0.212
# Epoch   2 Batch  518/538 - Train Accuracy:  0.350, Validation Accuracy:  0.420, Loss:  0.231
# Epoch   2 Batch  519/538 - Train Accuracy:  0.399, Validation Accuracy:  0.419, Loss:  0.216
# Epoch   2 Batch  520/538 - Train Accuracy:  0.335, Validation Accuracy:  0.421, Loss:  0.229
# Epoch   2 Batch  521/538 - Train Accuracy:  0.378, Validation Accuracy:  0.421, Loss:  0.231
# Epoch   2 Batch  522/538 - Train Accuracy:  0.350, Validation Accuracy:  0.419, Loss:  0.210
# Epoch   2 Batch  523/538 - Train Accuracy:  0.348, Validation Accuracy:  0.418, Loss:  0.211
# Epoch   2 Batch  524/538 - Train Accuracy:  0.332, Validation Accuracy:  0.418, Loss:  0.224
# Epoch   2 Batch  525/538 - Train Accuracy:  0.390, Validation Accuracy:  0.418, Loss:  0.210
# Epoch   2 Batch  526/538 - Train Accuracy:  0.376, Validation Accuracy:  0.417, Loss:  0.210
# Epoch   2 Batch  527/538 - Train Accuracy:  0.365, Validation Accuracy:  0.418, Loss:  0.219
# Epoch   2 Batch  528/538 - Train Accuracy:  0.326, Validation Accuracy:  0.420, Loss:  0.230
# Epoch   2 Batch  529/538 - Train Accuracy:  0.354, Validation Accuracy:  0.419, Loss:  0.211
# Epoch   2 Batch  530/538 - Train Accuracy:  0.352, Validation Accuracy:  0.419, Loss:  0.220
# Epoch   2 Batch  531/538 - Train Accuracy:  0.358, Validation Accuracy:  0.418, Loss:  0.215
# Epoch   2 Batch  532/538 - Train Accuracy:  0.348, Validation Accuracy:  0.419, Loss:  0.209
# Epoch   2 Batch  533/538 - Train Accuracy:  0.350, Validation Accuracy:  0.417, Loss:  0.217
# Epoch   2 Batch  534/538 - Train Accuracy:  0.369, Validation Accuracy:  0.416, Loss:  0.192
# Epoch   2 Batch  535/538 - Train Accuracy:  0.366, Validation Accuracy:  0.415, Loss:  0.203
# Epoch   2 Batch  536/538 - Train Accuracy:  0.376, Validation Accuracy:  0.415, Loss:  0.225
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    words_to_ids_array = []
    for word in sentence.split(" "):
        if(word in vocab_to_int):
            words_to_ids_array.append(vocab_to_int[word])
        else:
            words_to_ids_array.append(vocab_to_int["<UNK>"])
        
    return words_to_ids_array


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))
# Out:
# Input
#   Word Ids:      [129, 166, 109, 28, 93, 42, 32]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [237, 129, 34, 34, 34, 181, 181, 181, 181, 181, 0, 0, 0, 0, 0, 0, 0, 0]
#   French Words: ['il', 'a', 'la', 'la', 'la', '.', '.', '.', '.', '.', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
